# %% [markdown]
# # 4. Field of 11 inclined boreholes with curved trajectories : (b) Simulation
# The model is used to simulate the borefield over a 10-year period with variable heat extraction rate and fluid mass flow rate.

# %%
# Import necessary packages
import geothermsim as gs

import jax
from jax import numpy as jnp
from matplotlib import pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %% [markdown]
# ## 4(b).1. Borehole trajectories
# The position of the drill was recorded every 10 meters, nominally. The measurements are used to construct polynomial trajectories for the model.

# %%
# Points along the trajectories from the drilling logs

D = 2.
offset = jnp.array(
    [
        # [0., 0., -D],
        [0.375186, 1.79956, -D],
        [3.68243, 7.01754, -D],
        [-1.93403, 0.202918, -D],
        [4.92656, 5.57329, -D],
        [3.49819, 1.13551, -D],
        [0.684666, 9.22355, -D],
        [-0.8747, 8.149, -D],
        [0.639719, 4.73926, -D],
        [-5.41151, 0.675605, -D],
        [-2.86632, 2.43128, -D],
        [-2.50714, 7.098, -D],
    ]
)
p = [

        # Borehole 0 is not part of the system and only used for research
        # jnp.array([
        #     [0.00, 0.00, 0.],
        #     [0.01, 0.00, -10.],
        #     [-0.01, 0.01, -20.],
        #     [-0.02, 0.03, -30.],
        #     [0.00, 0.06, -40.],
        #     [0.04, 0.09, -50.],
        #     [0.09, 0.14, -60.],
        #     [0.17, 0.20, -70.],
        #     [0.27, 0.27, -80.],
        #     [0.40, 0.36, -90.],
        #     [0.55, 0.46, -100.],
        # ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [-0.61, 1.37, -9.84],
            [-0.38, 3.15, -19.68],
            [-0.14, 4.95, -29.51],
            [0.10, 6.73, -39.35],
            [0.28, 8.58, -49.18],
            [0.44, 10.47, -59.00],
            [0.55, 12.36, -68.81],
            [0.60, 14.29, -78.63],
            [0.64, 16.25, -88.43],
            [0.63, 18.27, -98.23],
            [0.57, 20.32, -108.01],
            [0.45, 22.41, -117.79],
            [0.29, 24.54, -127.56],
            [0.11, 26.68, -137.33],
            [-0.08, 28.82, -147.09],
            [-0.25, 30.99, -156.85],
            [-0.35, 33.21, -166.60],
            [-0.38, 35.42, -176.36],
            [-0.38, 37.63, -186.11],
            [-0.35, 39.89, -195.85],
            [-0.32, 42.19, -205.58],
            [-0.34, 44.50, -215.31],
            [-0.38, 45.66, -220.18],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [0.67, 0.54, -9.85],
            [2.16, -0.21, -19.71],
            [3.77, -0.81, -29.55],
            [5.55, -1.14, -39.39],
            [7.28, -1.71, -49.22],
            [9.02, -2.26, -59.05],
            [10.75, -2.63, -68.89],
            [12.47, -3.00, -78.73],
            [14.19, -3.22, -88.58],
            [15.88, -3.54, -98.43],
            [17.59, -3.86, -108.28],
            [19.33, -4.20, -118.12],
            [21.05, -4.61, -127.96],
            [22.82, -4.86, -137.80],
            [24.62, -5.16, -147.63],
            [26.36, -5.51, -157.47],
            [28.15, -5.74, -167.30],
            [30.01, -6.09, -177.12],
            [31.72, -6.62, -186.96],
            [33.31, -7.28, -196.81],
            [34.87, -7.90, -206.67],
            [36.33, -8.33, -216.55],
            [37.02, -8.57, -221.50],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [-0.05, -0.21, -9.85],
            [-1.77, -0.14, -19.70],
            [-3.44, -0.05, -29.56],
            [-5.06, 0.14, -39.42],
            [-6.64, 0.44, -49.30],
            [-8.24, 0.70, -59.16],
            [-9.91, 1.05, -69.02],
            [-11.58, 1.40, -78.87],
            [-13.26, 1.66, -88.72],
            [-14.93, 1.98, -98.58],
            [-16.56, 2.34, -108.44],
            [-18.07, 2.76, -118.31],
            [-19.51, 3.18, -128.20],
            [-20.86, 3.49, -138.10],
            [-22.10, 3.76, -148.02],
            [-23.30, 3.96, -157.95],
            [-24.46, 4.08, -167.88],
            [-25.57, 4.16, -177.82],
            [-26.63, 4.22, -187.76],
            [-27.70, 4.28, -197.70],
            [-28.76, 4.33, -207.65],
            [-29.79, 4.42, -217.59],
            [-30.29, 4.50, -222.57],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [0.52, 0.47, -9.97],
            [1.15, 0.78, -19.95],
            [1.78, 1.06, -29.92],
            [2.24, 1.60, -39.89],
            [2.65, 2.18, -49.87],
            [3.04, 2.78, -59.84],
            [3.43, 3.43, -69.81],
            [3.86, 4.13, -79.78],
            [4.34, 4.89, -89.74],
            [4.81, 5.66, -99.70],
            [5.27, 6.45, -109.66],
            [5.72, 7.27, -119.61],
            [6.19, 8.12, -129.56],
            [6.70, 9.02, -139.51],
            [7.29, 9.95, -149.45],
            [7.92, 10.88, -159.39],
            [8.59, 11.81, -169.32],
            [9.25, 12.72, -179.26],
            [9.93, 13.61, -189.19],
            [10.63, 14.50, -199.13],
            [11.29, 15.40, -209.07],
            [11.90, 16.28, -219.01],
            [12.52, 17.12, -228.96],
            [13.17, 17.92, -238.90],
            [13.84, 18.64, -248.85],
            [14.52, 19.30, -258.81],
            [15.19, 19.99, -268.76],
            [15.85, 20.69, -278.71],
            [16.53, 21.33, -288.67],
            [17.20, 21.99, -298.63],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [0.57, 0.73, -9.94],
            [1.58, 1.12, -19.88],
            [2.59, 1.49, -29.83],
            [3.65, 1.87, -39.76],
            [4.72, 2.30, -49.70],
            [5.82, 2.75, -59.63],
            [6.94, 3.26, -69.55],
            [8.05, 3.80, -79.47],
            [9.13, 4.34, -89.40],
            [10.21, 4.97, -99.32],
            [11.33, 5.62, -109.24],
            [12.50, 6.25, -119.15],
            [13.69, 6.86, -129.06],
            [14.86, 7.55, -138.96],
            [16.06, 8.30, -148.86],
            [17.33, 9.05, -158.75],
            [18.60, 9.81, -168.64],
            [19.88, 10.58, -178.53],
            [21.21, 11.35, -188.41],
            [22.63, 11.99, -198.29],
            [24.07, 12.59, -208.17],
            [25.51, 13.26, -218.04],
            [26.96, 13.87, -227.92],
            [28.38, 14.54, -237.79],
            [29.79, 15.29, -247.66],
            [31.23, 16.05, -257.53],
            [32.69, 16.81, -267.39],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [0.60, -0.09, -9.95],
            [1.52, -0.86, -19.88],
            [2.41, -1.68, -29.81],
            [3.33, -2.47, -39.73],
            [4.25, -3.22, -49.66],
            [5.20, -3.99, -59.59],
            [6.21, -4.76, -69.51],
            [7.22, -5.49, -79.43],
            [8.26, -6.18, -89.35],
            [9.35, -6.87, -99.27],
            [10.54, -7.57, -109.17],
            [11.74, -8.34, -119.07],
            [12.93, -9.17, -128.96],
            [14.21, -9.94, -138.85],
            [15.58, -10.70, -148.73],
            [17.02, -11.59, -158.58],
            [18.52, -12.60, -168.42],
            [19.90, -13.77, -178.25],
            [21.39, -14.93, -188.07],
            [23.10, -16.00, -197.86],
            [24.84, -17.13, -207.64],
            [26.63, -18.28, -217.41],
            [28.48, -19.45, -227.17],
            [30.36, -20.56, -236.93],
            [32.28, -21.69, -246.68],
            [34.22, -22.91, -256.41],
            [36.16, -24.21, -266.13],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [0.27, -0.36, -9.99],
            [0.50, -1.02, -19.96],
            [0.73, -1.65, -29.94],
            [0.95, -2.25, -39.92],
            [1.13, -2.85, -49.90],
            [1.34, -3.47, -59.88],
            [1.57, -4.09, -69.86],
            [1.75, -4.71, -79.83],
            [1.94, -5.36, -89.81],
            [2.21, -5.97, -99.79],
            [2.48, -6.58, -109.77],
            [2.71, -7.25, -119.74],
            [2.95, -7.93, -129.71],
            [3.21, -8.59, -139.69],
            [3.47, -9.31, -149.66],
            [3.83, -10.10, -159.62],
            [4.33, -10.91, -169.58],
            [4.90, -11.75, -179.52],
            [5.55, -12.66, -189.46],
            [6.28, -13.56, -199.39],
            [7.10, -14.49, -209.32],
            [7.98, -15.47, -219.23],
            [8.97, -16.51, -229.13],
            [10.03, -17.65, -239.00],
            [11.09, -18.91, -248.87],
            [12.16, -20.28, -258.72],
            [13.22, -21.73, -268.55],
            [14.28, -23.25, -278.38],
            [15.40, -24.86, -288.19],
            [16.56, -26.50, -297.98],
            [17.72, -28.18, -307.77],
            [18.82, -29.92, -317.56],
            [19.89, -31.68, -327.34],
            [20.92, -33.48, -337.12],
            [21.86, -35.36, -346.90],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [-0.09, -0.08, -9.98],
            [-0.40, -0.66, -19.96],
            [-0.74, -1.18, -29.94],
            [-1.11, -1.67, -39.92],
            [-1.47, -2.17, -49.90],
            [-1.86, -2.63, -59.89],
            [-2.29, -3.07, -69.87],
            [-2.73, -3.49, -79.85],
            [-3.21, -3.86, -89.83],
            [-3.72, -4.19, -99.81],
            [-4.25, -4.48, -109.79],
            [-4.74, -4.78, -119.78],
            [-5.19, -5.09, -129.76],
            [-5.60, -5.40, -139.75],
            [-5.96, -5.78, -149.73],
            [-6.26, -6.26, -159.72],
            [-6.48, -6.82, -169.70],
            [-6.64, -7.42, -179.68],
            [-6.81, -8.06, -189.66],
            [-6.94, -8.77, -199.63],
            [-7.02, -9.59, -209.60],
            [-7.10, -10.48, -219.56],
            [-7.13, -11.40, -229.52],
            [-7.09, -12.40, -239.46],
            [-6.93, -13.46, -249.41],
            [-6.66, -14.58, -259.34],
            [-6.38, -15.76, -269.27],
            [-6.17, -17.00, -279.19],
            [-6.00, -18.32, -289.10],
            [-5.83, -19.70, -299.00],
            [-5.66, -21.10, -308.90],
            [-5.48, -22.50, -318.80],
            [-5.31, -23.95, -328.69],
            [-5.19, -25.46, -338.58],
            [-5.10, -27.02, -348.45],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [-0.64, 0.32, -9.94],
            [-1.69, 0.00, -19.88],
            [-2.73, -0.35, -29.82],
            [-3.71, -0.70, -39.77],
            [-4.69, -1.03, -49.72],
            [-5.67, -1.32, -59.66],
            [-6.65, -1.57, -69.61],
            [-7.62, -1.81, -79.56],
            [-8.59, -2.07, -89.51],
            [-9.54, -2.35, -99.46],
            [-10.48, -2.66, -109.41],
            [-11.38, -2.99, -119.37],
            [-12.25, -3.33, -129.32],
            [-13.09, -3.69, -139.28],
            [-13.86, -4.19, -149.24],
            [-14.58, -4.85, -159.19],
            [-15.22, -5.61, -169.14],
            [-15.79, -6.48, -179.09],
            [-16.33, -7.49, -189.02],
            [-16.88, -8.71, -198.93],
            [-17.48, -10.07, -208.82],
            [-18.13, -11.47, -218.70],
            [-18.81, -12.90, -228.57],
            [-19.46, -14.39, -238.44],
            [-20.06, -15.93, -248.30],
            [-20.57, -17.49, -258.17],
            [-20.91, -19.08, -268.03],
            [-21.15, -20.72, -277.89],
            [-21.34, -22.41, -287.75],
            [-21.49, -24.14, -297.60],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [-1.06, 0.35, -9.92],
            [-1.99, 1.19, -19.85],
            [-2.94, 2.00, -29.77],
            [-3.96, 2.78, -39.68],
            [-4.98, 3.57, -49.60],
            [-5.91, 4.34, -59.53],
            [-6.84, 5.12, -69.45],
            [-7.83, 5.94, -79.37],
            [-8.89, 6.83, -89.27],
            [-9.99, 7.76, -99.17],
            [-11.14, 8.67, -109.06],
            [-12.28, 9.58, -118.95],
            [-13.40, 10.49, -128.85],
            [-14.50, 11.39, -138.75],
            [-15.64, 12.20, -148.65],
            [-16.80, 12.90, -158.56],
            [-17.95, 13.59, -168.47],
            [-19.13, 14.27, -178.37],
            [-20.29, 15.00, -188.28],
            [-21.41, 15.80, -198.18],
            [-22.52, 16.56, -208.09],
            [-23.65, 17.32, -218.00],
            [-24.79, 18.07, -227.91],
            [-25.97, 18.79, -237.81],
            [-27.15, 19.52, -247.71],
            [-28.33, 20.27, -257.61],
            [-29.57, 21.01, -267.51],
        ]),

        jnp.array([
            [0.00, 0.00, 0.00],
            [-0.64, 0.31, -9.96],
            [-0.94, 0.97, -19.93],
            [-1.30, 1.61, -29.91],
            [-1.62, 2.29, -39.88],
            [-1.88, 2.99, -49.85],
            [-2.19, 3.67, -59.82],
            [-2.51, 4.45, -69.79],
            [-2.82, 5.23, -79.75],
            [-3.21, 5.94, -89.72],
            [-3.60, 6.72, -99.68],
            [-3.94, 7.51, -109.64],
            [-4.33, 8.30, -119.60],
            [-4.76, 9.14, -129.56],
            [-5.10, 10.00, -139.52],
            [-5.37, 10.84, -149.48],
            [-5.63, 11.70, -159.44],
            [-5.92, 12.60, -169.39],
            [-6.24, 13.53, -179.34],
            [-6.48, 14.48, -189.29],
            [-6.67, 15.42, -199.25],
            [-6.87, 16.36, -209.20],
            [-7.01, 17.30, -219.16],
            [-7.12, 18.23, -229.11],
            [-7.28, 19.12, -239.07],
            [-7.47, 20.00, -249.03],
            [-7.68, 20.86, -258.99],
            [-7.89, 21.68, -268.96],
            [-8.09, 22.45, -278.92],
            [-8.31, 23.16, -288.90],
            [-8.57, 23.83, -298.87],
        ])

    ]

p = [_p + _offset for _p, _offset in zip(p, offset)]

# %% [markdown]
# A 6th order polynomial is used to represent the trajectory of each borehole.

# %%
paths = [gs.Path.Polynomial(jnp.linspace(-1., 1., num=_p.shape[0]), _p, deg=5) for _p in p]

# %% [markdown]
# # 4(b).2. Simulation of the borefield

# %% [markdown]
# ### 4(b).2.1. Simulation parameters

# %%
# Borehole dimensions
r_b = 0.075         # Borehole radius (m)

# Pipe dimensions
r_out = 0.0211      # Pipe outer radius (m)
r_in = 0.0147       # Pipe inner radius (m)
D_s = 0.052         # Shank spacing (m)
epsilon = 2.12e-5   # Pipe roughness (m)

# Pipe positions
# Single U-tube : [[x_in, y_in], [x_out, y_out]]
p_pipes = jnp.array([[-D_s, 0.], [D_s, 0.]])

# Ground properties
alpha = 1.0e-6      # Ground thermal diffusivity (m2/s)
k_s = 2.0           # Ground thermal conductivity (W/m.K)

# Grout properties
k_b = 1.0           # Grout thermal conductivity (W/m.K)

# Pipe properties
k_p = 0.4           # Pipe thermal conductivity (W/m.K)

# Fluid properties
m_flow_borehole = 0.375 # Total fluid mass flow rate per borehole (kg/s)
m_flow_network = m_flow_borehole * len(paths)  # Fluid mass flow rate (in kg/s)
# The fluid is propylene-glycol (20 %) at 20 degC
T_nominal = 20.
fluid = gs.Fluid.from_scp(
    'PropyleneGlycol', T_nominal, x=0.2
)
cp_f = fluid.specific_heat()  # Fluid specific heat capacity (in J/kg.K)

# %%
dt = 3600.              # Time step
tmax = 10 * 8760 * 3600.    # Maximum time
alpha = 1e-6
k_s = 2.
T0 = 10.

# %% [markdown]
# ### 4(b).2.2. Initialization of `Borefield` object
# 5 segments of 7 nodes are used for the evaluation of the $g$-functions. The trajectories of the boreholes are very close near the top. The discretization is thus refined near the top of the boreholes.

# %%
n_nodes = 7
n_segments = 5
segment_ratios = jnp.array([0.05, 0.1, 0.3, 0.3, 0.25])
basis = gs.Basis.Legendre(n_nodes)

# %%
ground_heat_exchanger = gs.UTubeHeatExchanger(
    p_pipes, r_in, r_out, r_b, fluid, k_s, k_b, k_p, epsilon)
R_d = ground_heat_exchanger.thermal_resistances
boreholes = [
    gs.SingleUTube(R_d, fluid, r_b, path, basis, n_segments, segment_ratios=segment_ratios)
    for path in paths
]
borefield = gs.Network(boreholes, fluid)

# %% [markdown]
# ### 4(b).2.3. Simulation
# The simulation uses the synthetic asymmetric heat extraction rate profile of Pinel [1]. The profile is repeated every year of the simulation and scaled by `18.53` since the original profile was intended for a single borehole. This number is chosen so that the maximum temperature difference is 5 degrees Celsius at peak.

# %%
def synthetic_load(x, scaling=1):
    """
    Synthetic load profile of Pinel (2003).

    Returns load y (in watts) at time x (in seconds).
    """
    x = x / 3600.
    A = 2000.
    B = 1000.
    C = 80.0
    D = 4. / 3
    E = 0.01
    F = 2190.
    G = 0.95

    q_1 = A * jnp.sin(jnp.pi / 12 * (x - B)) * jnp.sin(D * jnp.pi / 8760 * (x - B))

    i = jnp.arange(1, 4)
    q_2 = (168. - C) / 168
    for _i in i:
        q_2 = q_2 + 1. / (_i * jnp.pi) * (jnp.cos(C * jnp.pi * _i / 84.) - 1) * jnp.sin(jnp.pi * _i / 84 * (x - B))
    FL = jnp.floor(D / 8760 * (x - B))
    SN = jnp.sign(jnp.cos(D * jnp.pi / 4380 * (x + F)) + G)

    y = q_1 * q_2 + (-1)**FL * jnp.abs(q_1 * q_2) + E * (-1)**FL * SN
    return -y * scaling

# %%
time = jnp.arange(1, 8761) * 3600.
Q = synthetic_load(time, scaling=18.53)

# %% [markdown]
# The fluid mass flow rate is modulated proportionally to the heat extraction/injection rate to keep a constant 5 degree Celsius difference between inlet and outlet, with a minimum fluid mass flow rate of 30% of the maximum.

# %%
def f_m_flow(_Q, Q_small=1.):
    return jnp.maximum(0.3 * m_flow_network, jnp.abs(_Q) / (5 * cp_f)) * jnp.heaviside(jnp.abs(_Q) - Q_small, 1.)

# %% [markdown]
# Simulate the system. This takes about 20-30 minutes.

# %%
simulation = gs.Simulation(borefield, dt, tmax, T0, alpha, k_s)
simulation.simulate(Q, f_m_flow)
# Out:
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.96 seconds.
# Initialization end. Elapsed time: 3.97 seconds.
# Simulation start.
# Completed 100 of 87600 time steps.
# Completed 200 of 87600 time steps.
# Completed 300 of 87600 time steps.
# Completed 400 of 87600 time steps.
# Completed 500 of 87600 time steps.
# Completed 600 of 87600 time steps.
# Completed 700 of 87600 time steps.
# Completed 800 of 87600 time steps.
# Completed 900 of 87600 time steps.
# Completed 1000 of 87600 time steps.
# Completed 1100 of 87600 time steps.
# Completed 1200 of 87600 time steps.
# Completed 1300 of 87600 time steps.
# Completed 1400 of 87600 time steps.
# Completed 1500 of 87600 time steps.
# Completed 1600 of 87600 time steps.
# Completed 1700 of 87600 time steps.
# Completed 1800 of 87600 time steps.
# Completed 1900 of 87600 time steps.
# Completed 2000 of 87600 time steps.
# Completed 2100 of 87600 time steps.
# Completed 2200 of 87600 time steps.
# Completed 2300 of 87600 time steps.
# Completed 2400 of 87600 time steps.
# Completed 2500 of 87600 time steps.
# Completed 2600 of 87600 time steps.
# Completed 2700 of 87600 time steps.
# Completed 2800 of 87600 time steps.
# Completed 2900 of 87600 time steps.
# Completed 3000 of 87600 time steps.
# Completed 3100 of 87600 time steps.
# Completed 3200 of 87600 time steps.
# Completed 3300 of 87600 time steps.
# Completed 3400 of 87600 time steps.
# Completed 3500 of 87600 time steps.
# Completed 3600 of 87600 time steps.
# Completed 3700 of 87600 time steps.
# Completed 3800 of 87600 time steps.
# Completed 3900 of 87600 time steps.
# Completed 4000 of 87600 time steps.
# Completed 4100 of 87600 time steps.
# Completed 4200 of 87600 time steps.
# Completed 4300 of 87600 time steps.
# Completed 4400 of 87600 time steps.
# Completed 4500 of 87600 time steps.
# Completed 4600 of 87600 time steps.
# Completed 4700 of 87600 time steps.
# Completed 4800 of 87600 time steps.
# Completed 4900 of 87600 time steps.
# Completed 5000 of 87600 time steps.
# Completed 5100 of 87600 time steps.
# Completed 5200 of 87600 time steps.
# Completed 5300 of 87600 time steps.
# Completed 5400 of 87600 time steps.
# Completed 5500 of 87600 time steps.
# Completed 5600 of 87600 time steps.
# Completed 5700 of 87600 time steps.
# Completed 5800 of 87600 time steps.
# Completed 5900 of 87600 time steps.
# Completed 6000 of 87600 time steps.
# Completed 6100 of 87600 time steps.
# Completed 6200 of 87600 time steps.
# Completed 6300 of 87600 time steps.
# Completed 6400 of 87600 time steps.
# Completed 6500 of 87600 time steps.
# Completed 6600 of 87600 time steps.
# Completed 6700 of 87600 time steps.
# Completed 6800 of 87600 time steps.
# Completed 6900 of 87600 time steps.
# Completed 7000 of 87600 time steps.
# Completed 7100 of 87600 time steps.
# Completed 7200 of 87600 time steps.
# Completed 7300 of 87600 time steps.
# Completed 7400 of 87600 time steps.
# Completed 7500 of 87600 time steps.
# Completed 7600 of 87600 time steps.
# Completed 7700 of 87600 time steps.
# Completed 7800 of 87600 time steps.
# Completed 7900 of 87600 time steps.
# Completed 8000 of 87600 time steps.
# Completed 8100 of 87600 time steps.
# Completed 8200 of 87600 time steps.
# Completed 8300 of 87600 time steps.
# Completed 8400 of 87600 time steps.
# Completed 8500 of 87600 time steps.
# Completed 8600 of 87600 time steps.
# Completed 8700 of 87600 time steps.
# Completed 8800 of 87600 time steps.
# Completed 8900 of 87600 time steps.
# Completed 9000 of 87600 time steps.
# Completed 9100 of 87600 time steps.
# Completed 9200 of 87600 time steps.
# Completed 9300 of 87600 time steps.
# Completed 9400 of 87600 time steps.
# Completed 9500 of 87600 time steps.
# Completed 9600 of 87600 time steps.
# Completed 9700 of 87600 time steps.
# Completed 9800 of 87600 time steps.
# Completed 9900 of 87600 time steps.
# Completed 10000 of 87600 time steps.
# Completed 10100 of 87600 time steps.
# Completed 10200 of 87600 time steps.
# Completed 10300 of 87600 time steps.
# Completed 10400 of 87600 time steps.
# Completed 10500 of 87600 time steps.
# Completed 10600 of 87600 time steps.
# Completed 10700 of 87600 time steps.
# Completed 10800 of 87600 time steps.
# Completed 10900 of 87600 time steps.
# Completed 11000 of 87600 time steps.
# Completed 11100 of 87600 time steps.
# Completed 11200 of 87600 time steps.
# Completed 11300 of 87600 time steps.
# Completed 11400 of 87600 time steps.
# Completed 11500 of 87600 time steps.
# Completed 11600 of 87600 time steps.
# Completed 11700 of 87600 time steps.
# Completed 11800 of 87600 time steps.
# Completed 11900 of 87600 time steps.
# Completed 12000 of 87600 time steps.
# Completed 12100 of 87600 time steps.
# Completed 12200 of 87600 time steps.
# Completed 12300 of 87600 time steps.
# Completed 12400 of 87600 time steps.
# Completed 12500 of 87600 time steps.
# Completed 12600 of 87600 time steps.
# Completed 12700 of 87600 time steps.
# Completed 12800 of 87600 time steps.
# Completed 12900 of 87600 time steps.
# Completed 13000 of 87600 time steps.
# Completed 13100 of 87600 time steps.
# Completed 13200 of 87600 time steps.
# Completed 13300 of 87600 time steps.
# Completed 13400 of 87600 time steps.
# Completed 13500 of 87600 time steps.
# Completed 13600 of 87600 time steps.
# Completed 13700 of 87600 time steps.
# Completed 13800 of 87600 time steps.
# Completed 13900 of 87600 time steps.
# Completed 14000 of 87600 time steps.
# Completed 14100 of 87600 time steps.
# Completed 14200 of 87600 time steps.
# Completed 14300 of 87600 time steps.
# Completed 14400 of 87600 time steps.
# Completed 14500 of 87600 time steps.
# Completed 14600 of 87600 time steps.
# Completed 14700 of 87600 time steps.
# Completed 14800 of 87600 time steps.
# Completed 14900 of 87600 time steps.
# Completed 15000 of 87600 time steps.
# Completed 15100 of 87600 time steps.
# Completed 15200 of 87600 time steps.
# Completed 15300 of 87600 time steps.
# Completed 15400 of 87600 time steps.
# Completed 15500 of 87600 time steps.
# Completed 15600 of 87600 time steps.
# Completed 15700 of 87600 time steps.
# Completed 15800 of 87600 time steps.
# Completed 15900 of 87600 time steps.
# Completed 16000 of 87600 time steps.
# Completed 16100 of 87600 time steps.
# Completed 16200 of 87600 time steps.
# Completed 16300 of 87600 time steps.
# Completed 16400 of 87600 time steps.
# Completed 16500 of 87600 time steps.
# Completed 16600 of 87600 time steps.
# Completed 16700 of 87600 time steps.
# Completed 16800 of 87600 time steps.
# Completed 16900 of 87600 time steps.
# Completed 17000 of 87600 time steps.
# Completed 17100 of 87600 time steps.
# Completed 17200 of 87600 time steps.
# Completed 17300 of 87600 time steps.
# Completed 17400 of 87600 time steps.
# Completed 17500 of 87600 time steps.
# Completed 17600 of 87600 time steps.
# Completed 17700 of 87600 time steps.
# Completed 17800 of 87600 time steps.
# Completed 17900 of 87600 time steps.
# Completed 18000 of 87600 time steps.
# Completed 18100 of 87600 time steps.
# Completed 18200 of 87600 time steps.
# Completed 18300 of 87600 time steps.
# Completed 18400 of 87600 time steps.
# Completed 18500 of 87600 time steps.
# Completed 18600 of 87600 time steps.
# Completed 18700 of 87600 time steps.
# Completed 18800 of 87600 time steps.
# Completed 18900 of 87600 time steps.
# Completed 19000 of 87600 time steps.
# Completed 19100 of 87600 time steps.
# Completed 19200 of 87600 time steps.
# Completed 19300 of 87600 time steps.
# Completed 19400 of 87600 time steps.
# Completed 19500 of 87600 time steps.
# Completed 19600 of 87600 time steps.
# Completed 19700 of 87600 time steps.
# Completed 19800 of 87600 time steps.
# Completed 19900 of 87600 time steps.
# Completed 20000 of 87600 time steps.
# Completed 20100 of 87600 time steps.
# Completed 20200 of 87600 time steps.
# Completed 20300 of 87600 time steps.
# Completed 20400 of 87600 time steps.
# Completed 20500 of 87600 time steps.
# Completed 20600 of 87600 time steps.
# Completed 20700 of 87600 time steps.
# Completed 20800 of 87600 time steps.
# Completed 20900 of 87600 time steps.
# Completed 21000 of 87600 time steps.
# Completed 21100 of 87600 time steps.
# Completed 21200 of 87600 time steps.
# Completed 21300 of 87600 time steps.
# Completed 21400 of 87600 time steps.
# Completed 21500 of 87600 time steps.
# Completed 21600 of 87600 time steps.
# Completed 21700 of 87600 time steps.
# Completed 21800 of 87600 time steps.
# Completed 21900 of 87600 time steps.
# Completed 22000 of 87600 time steps.
# Completed 22100 of 87600 time steps.
# Completed 22200 of 87600 time steps.
# Completed 22300 of 87600 time steps.
# Completed 22400 of 87600 time steps.
# Completed 22500 of 87600 time steps.
# Completed 22600 of 87600 time steps.
# Completed 22700 of 87600 time steps.
# Completed 22800 of 87600 time steps.
# Completed 22900 of 87600 time steps.
# Completed 23000 of 87600 time steps.
# Completed 23100 of 87600 time steps.
# Completed 23200 of 87600 time steps.
# Completed 23300 of 87600 time steps.
# Completed 23400 of 87600 time steps.
# Completed 23500 of 87600 time steps.
# Completed 23600 of 87600 time steps.
# Completed 23700 of 87600 time steps.
# Completed 23800 of 87600 time steps.
# Completed 23900 of 87600 time steps.
# Completed 24000 of 87600 time steps.
# Completed 24100 of 87600 time steps.
# Completed 24200 of 87600 time steps.
# Completed 24300 of 87600 time steps.
# Completed 24400 of 87600 time steps.
# Completed 24500 of 87600 time steps.
# Completed 24600 of 87600 time steps.
# Completed 24700 of 87600 time steps.
# Completed 24800 of 87600 time steps.
# Completed 24900 of 87600 time steps.
# Completed 25000 of 87600 time steps.
# Completed 25100 of 87600 time steps.
# Completed 25200 of 87600 time steps.
# Completed 25300 of 87600 time steps.
# Completed 25400 of 87600 time steps.
# Completed 25500 of 87600 time steps.
# Completed 25600 of 87600 time steps.
# Completed 25700 of 87600 time steps.
# Completed 25800 of 87600 time steps.
# Completed 25900 of 87600 time steps.
# Completed 26000 of 87600 time steps.
# Completed 26100 of 87600 time steps.
# Completed 26200 of 87600 time steps.
# Completed 26300 of 87600 time steps.
# Completed 26400 of 87600 time steps.
# Completed 26500 of 87600 time steps.
# Completed 26600 of 87600 time steps.
# Completed 26700 of 87600 time steps.
# Completed 26800 of 87600 time steps.
# Completed 26900 of 87600 time steps.
# Completed 27000 of 87600 time steps.
# Completed 27100 of 87600 time steps.
# Completed 27200 of 87600 time steps.
# Completed 27300 of 87600 time steps.
# Completed 27400 of 87600 time steps.
# Completed 27500 of 87600 time steps.
# Completed 27600 of 87600 time steps.
# Completed 27700 of 87600 time steps.
# Completed 27800 of 87600 time steps.
# Completed 27900 of 87600 time steps.
# Completed 28000 of 87600 time steps.
# Completed 28100 of 87600 time steps.
# Completed 28200 of 87600 time steps.
# Completed 28300 of 87600 time steps.
# Completed 28400 of 87600 time steps.
# Completed 28500 of 87600 time steps.
# Completed 28600 of 87600 time steps.
# Completed 28700 of 87600 time steps.
# Completed 28800 of 87600 time steps.
# Completed 28900 of 87600 time steps.
# Completed 29000 of 87600 time steps.
# Completed 29100 of 87600 time steps.
# Completed 29200 of 87600 time steps.
# Completed 29300 of 87600 time steps.
# Completed 29400 of 87600 time steps.
# Completed 29500 of 87600 time steps.
# Completed 29600 of 87600 time steps.
# Completed 29700 of 87600 time steps.
# Completed 29800 of 87600 time steps.
# Completed 29900 of 87600 time steps.
# Completed 30000 of 87600 time steps.
# Completed 30100 of 87600 time steps.
# Completed 30200 of 87600 time steps.
# Completed 30300 of 87600 time steps.
# Completed 30400 of 87600 time steps.
# Completed 30500 of 87600 time steps.
# Completed 30600 of 87600 time steps.
# Completed 30700 of 87600 time steps.
# Completed 30800 of 87600 time steps.
# Completed 30900 of 87600 time steps.
# Completed 31000 of 87600 time steps.
# Completed 31100 of 87600 time steps.
# Completed 31200 of 87600 time steps.
# Completed 31300 of 87600 time steps.
# Completed 31400 of 87600 time steps.
# Completed 31500 of 87600 time steps.
# Completed 31600 of 87600 time steps.
# Completed 31700 of 87600 time steps.
# Completed 31800 of 87600 time steps.
# Completed 31900 of 87600 time steps.
# Completed 32000 of 87600 time steps.
# Completed 32100 of 87600 time steps.
# Completed 32200 of 87600 time steps.
# Completed 32300 of 87600 time steps.
# Completed 32400 of 87600 time steps.
# Completed 32500 of 87600 time steps.
# Completed 32600 of 87600 time steps.
# Completed 32700 of 87600 time steps.
# Completed 32800 of 87600 time steps.
# Completed 32900 of 87600 time steps.
# Completed 33000 of 87600 time steps.
# Completed 33100 of 87600 time steps.
# Completed 33200 of 87600 time steps.
# Completed 33300 of 87600 time steps.
# Completed 33400 of 87600 time steps.
# Completed 33500 of 87600 time steps.
# Completed 33600 of 87600 time steps.
# Completed 33700 of 87600 time steps.
# Completed 33800 of 87600 time steps.
# Completed 33900 of 87600 time steps.
# Completed 34000 of 87600 time steps.
# Completed 34100 of 87600 time steps.
# Completed 34200 of 87600 time steps.
# Completed 34300 of 87600 time steps.
# Completed 34400 of 87600 time steps.
# Completed 34500 of 87600 time steps.
# Completed 34600 of 87600 time steps.
# Completed 34700 of 87600 time steps.
# Completed 34800 of 87600 time steps.
# Completed 34900 of 87600 time steps.
# Completed 35000 of 87600 time steps.
# Completed 35100 of 87600 time steps.
# Completed 35200 of 87600 time steps.
# Completed 35300 of 87600 time steps.
# Completed 35400 of 87600 time steps.
# Completed 35500 of 87600 time steps.
# Completed 35600 of 87600 time steps.
# Completed 35700 of 87600 time steps.
# Completed 35800 of 87600 time steps.
# Completed 35900 of 87600 time steps.
# Completed 36000 of 87600 time steps.
# Completed 36100 of 87600 time steps.
# Completed 36200 of 87600 time steps.
# Completed 36300 of 87600 time steps.
# Completed 36400 of 87600 time steps.
# Completed 36500 of 87600 time steps.
# Completed 36600 of 87600 time steps.
# Completed 36700 of 87600 time steps.
# Completed 36800 of 87600 time steps.
# Completed 36900 of 87600 time steps.
# Completed 37000 of 87600 time steps.
# Completed 37100 of 87600 time steps.
# Completed 37200 of 87600 time steps.
# Completed 37300 of 87600 time steps.
# Completed 37400 of 87600 time steps.
# Completed 37500 of 87600 time steps.
# Completed 37600 of 87600 time steps.
# Completed 37700 of 87600 time steps.
# Completed 37800 of 87600 time steps.
# Completed 37900 of 87600 time steps.
# Completed 38000 of 87600 time steps.
# Completed 38100 of 87600 time steps.
# Completed 38200 of 87600 time steps.
# Completed 38300 of 87600 time steps.
# Completed 38400 of 87600 time steps.
# Completed 38500 of 87600 time steps.
# Completed 38600 of 87600 time steps.
# Completed 38700 of 87600 time steps.
# Completed 38800 of 87600 time steps.
# Completed 38900 of 87600 time steps.
# Completed 39000 of 87600 time steps.
# Completed 39100 of 87600 time steps.
# Completed 39200 of 87600 time steps.
# Completed 39300 of 87600 time steps.
# Completed 39400 of 87600 time steps.
# Completed 39500 of 87600 time steps.
# Completed 39600 of 87600 time steps.
# Completed 39700 of 87600 time steps.
# Completed 39800 of 87600 time steps.
# Completed 39900 of 87600 time steps.
# Completed 40000 of 87600 time steps.
# Completed 40100 of 87600 time steps.
# Completed 40200 of 87600 time steps.
# Completed 40300 of 87600 time steps.
# Completed 40400 of 87600 time steps.
# Completed 40500 of 87600 time steps.
# Completed 40600 of 87600 time steps.
# Completed 40700 of 87600 time steps.
# Completed 40800 of 87600 time steps.
# Completed 40900 of 87600 time steps.
# Completed 41000 of 87600 time steps.
# Completed 41100 of 87600 time steps.
# Completed 41200 of 87600 time steps.
# Completed 41300 of 87600 time steps.
# Completed 41400 of 87600 time steps.
# Completed 41500 of 87600 time steps.
# Completed 41600 of 87600 time steps.
# Completed 41700 of 87600 time steps.
# Completed 41800 of 87600 time steps.
# Completed 41900 of 87600 time steps.
# Completed 42000 of 87600 time steps.
# Completed 42100 of 87600 time steps.
# Completed 42200 of 87600 time steps.
# Completed 42300 of 87600 time steps.
# Completed 42400 of 87600 time steps.
# Completed 42500 of 87600 time steps.
# Completed 42600 of 87600 time steps.
# Completed 42700 of 87600 time steps.
# Completed 42800 of 87600 time steps.
# Completed 42900 of 87600 time steps.
# Completed 43000 of 87600 time steps.
# Completed 43100 of 87600 time steps.
# Completed 43200 of 87600 time steps.
# Completed 43300 of 87600 time steps.
# Completed 43400 of 87600 time steps.
# Completed 43500 of 87600 time steps.
# Completed 43600 of 87600 time steps.
# Completed 43700 of 87600 time steps.
# Completed 43800 of 87600 time steps.
# Completed 43900 of 87600 time steps.
# Completed 44000 of 87600 time steps.
# Completed 44100 of 87600 time steps.
# Completed 44200 of 87600 time steps.
# Completed 44300 of 87600 time steps.
# Completed 44400 of 87600 time steps.
# Completed 44500 of 87600 time steps.
# Completed 44600 of 87600 time steps.
# Completed 44700 of 87600 time steps.
# Completed 44800 of 87600 time steps.
# Completed 44900 of 87600 time steps.
# Completed 45000 of 87600 time steps.
# Completed 45100 of 87600 time steps.
# Completed 45200 of 87600 time steps.
# Completed 45300 of 87600 time steps.
# Completed 45400 of 87600 time steps.
# Completed 45500 of 87600 time steps.
# Completed 45600 of 87600 time steps.
# Completed 45700 of 87600 time steps.
# Completed 45800 of 87600 time steps.
# Completed 45900 of 87600 time steps.
# Completed 46000 of 87600 time steps.
# Completed 46100 of 87600 time steps.
# Completed 46200 of 87600 time steps.
# Completed 46300 of 87600 time steps.
# Completed 46400 of 87600 time steps.
# Completed 46500 of 87600 time steps.
# Completed 46600 of 87600 time steps.
# Completed 46700 of 87600 time steps.
# Completed 46800 of 87600 time steps.
# Completed 46900 of 87600 time steps.
# Completed 47000 of 87600 time steps.
# Completed 47100 of 87600 time steps.
# Completed 47200 of 87600 time steps.
# Completed 47300 of 87600 time steps.
# Completed 47400 of 87600 time steps.
# Completed 47500 of 87600 time steps.
# Completed 47600 of 87600 time steps.
# Completed 47700 of 87600 time steps.
# Completed 47800 of 87600 time steps.
# Completed 47900 of 87600 time steps.
# Completed 48000 of 87600 time steps.
# Completed 48100 of 87600 time steps.
# Completed 48200 of 87600 time steps.
# Completed 48300 of 87600 time steps.
# Completed 48400 of 87600 time steps.
# Completed 48500 of 87600 time steps.
# Completed 48600 of 87600 time steps.
# Completed 48700 of 87600 time steps.
# Completed 48800 of 87600 time steps.
# Completed 48900 of 87600 time steps.
# Completed 49000 of 87600 time steps.
# Completed 49100 of 87600 time steps.
# Completed 49200 of 87600 time steps.
# Completed 49300 of 87600 time steps.
# Completed 49400 of 87600 time steps.
# Completed 49500 of 87600 time steps.
# Completed 49600 of 87600 time steps.
# Completed 49700 of 87600 time steps.
# Completed 49800 of 87600 time steps.
# Completed 49900 of 87600 time steps.
# Completed 50000 of 87600 time steps.
# Completed 50100 of 87600 time steps.
# Completed 50200 of 87600 time steps.
# Completed 50300 of 87600 time steps.
# Completed 50400 of 87600 time steps.
# Completed 50500 of 87600 time steps.
# Completed 50600 of 87600 time steps.
# Completed 50700 of 87600 time steps.
# Completed 50800 of 87600 time steps.
# Completed 50900 of 87600 time steps.
# Completed 51000 of 87600 time steps.
# Completed 51100 of 87600 time steps.
# Completed 51200 of 87600 time steps.
# Completed 51300 of 87600 time steps.
# Completed 51400 of 87600 time steps.
# Completed 51500 of 87600 time steps.
# Completed 51600 of 87600 time steps.
# Completed 51700 of 87600 time steps.
# Completed 51800 of 87600 time steps.
# Completed 51900 of 87600 time steps.
# Completed 52000 of 87600 time steps.
# Completed 52100 of 87600 time steps.
# Completed 52200 of 87600 time steps.
# Completed 52300 of 87600 time steps.
# Completed 52400 of 87600 time steps.
# Completed 52500 of 87600 time steps.
# Completed 52600 of 87600 time steps.
# Completed 52700 of 87600 time steps.
# Completed 52800 of 87600 time steps.
# Completed 52900 of 87600 time steps.
# Completed 53000 of 87600 time steps.
# Completed 53100 of 87600 time steps.
# Completed 53200 of 87600 time steps.
# Completed 53300 of 87600 time steps.
# Completed 53400 of 87600 time steps.
# Completed 53500 of 87600 time steps.
# Completed 53600 of 87600 time steps.
# Completed 53700 of 87600 time steps.
# Completed 53800 of 87600 time steps.
# Completed 53900 of 87600 time steps.
# Completed 54000 of 87600 time steps.
# Completed 54100 of 87600 time steps.
# Completed 54200 of 87600 time steps.
# Completed 54300 of 87600 time steps.
# Completed 54400 of 87600 time steps.
# Completed 54500 of 87600 time steps.
# Completed 54600 of 87600 time steps.
# Completed 54700 of 87600 time steps.
# Completed 54800 of 87600 time steps.
# Completed 54900 of 87600 time steps.
# Completed 55000 of 87600 time steps.
# Completed 55100 of 87600 time steps.
# Completed 55200 of 87600 time steps.
# Completed 55300 of 87600 time steps.
# Completed 55400 of 87600 time steps.
# Completed 55500 of 87600 time steps.
# Completed 55600 of 87600 time steps.
# Completed 55700 of 87600 time steps.
# Completed 55800 of 87600 time steps.
# Completed 55900 of 87600 time steps.
# Completed 56000 of 87600 time steps.
# Completed 56100 of 87600 time steps.
# Completed 56200 of 87600 time steps.
# Completed 56300 of 87600 time steps.
# Completed 56400 of 87600 time steps.
# Completed 56500 of 87600 time steps.
# Completed 56600 of 87600 time steps.
# Completed 56700 of 87600 time steps.
# Completed 56800 of 87600 time steps.
# Completed 56900 of 87600 time steps.
# Completed 57000 of 87600 time steps.
# Completed 57100 of 87600 time steps.
# Completed 57200 of 87600 time steps.
# Completed 57300 of 87600 time steps.
# Completed 57400 of 87600 time steps.
# Completed 57500 of 87600 time steps.
# Completed 57600 of 87600 time steps.
# Completed 57700 of 87600 time steps.
# Completed 57800 of 87600 time steps.
# Completed 57900 of 87600 time steps.
# Completed 58000 of 87600 time steps.
# Completed 58100 of 87600 time steps.
# Completed 58200 of 87600 time steps.
# Completed 58300 of 87600 time steps.
# Completed 58400 of 87600 time steps.
# Completed 58500 of 87600 time steps.
# Completed 58600 of 87600 time steps.
# Completed 58700 of 87600 time steps.
# Completed 58800 of 87600 time steps.
# Completed 58900 of 87600 time steps.
# Completed 59000 of 87600 time steps.
# Completed 59100 of 87600 time steps.
# Completed 59200 of 87600 time steps.
# Completed 59300 of 87600 time steps.
# Completed 59400 of 87600 time steps.
# Completed 59500 of 87600 time steps.
# Completed 59600 of 87600 time steps.
# Completed 59700 of 87600 time steps.
# Completed 59800 of 87600 time steps.
# Completed 59900 of 87600 time steps.
# Completed 60000 of 87600 time steps.
# Completed 60100 of 87600 time steps.
# Completed 60200 of 87600 time steps.
# Completed 60300 of 87600 time steps.
# Completed 60400 of 87600 time steps.
# Completed 60500 of 87600 time steps.
# Completed 60600 of 87600 time steps.
# Completed 60700 of 87600 time steps.
# Completed 60800 of 87600 time steps.
# Completed 60900 of 87600 time steps.
# Completed 61000 of 87600 time steps.
# Completed 61100 of 87600 time steps.
# Completed 61200 of 87600 time steps.
# Completed 61300 of 87600 time steps.
# Completed 61400 of 87600 time steps.
# Completed 61500 of 87600 time steps.
# Completed 61600 of 87600 time steps.
# Completed 61700 of 87600 time steps.
# Completed 61800 of 87600 time steps.
# Completed 61900 of 87600 time steps.
# Completed 62000 of 87600 time steps.
# Completed 62100 of 87600 time steps.
# Completed 62200 of 87600 time steps.
# Completed 62300 of 87600 time steps.
# Completed 62400 of 87600 time steps.
# Completed 62500 of 87600 time steps.
# Completed 62600 of 87600 time steps.
# Completed 62700 of 87600 time steps.
# Completed 62800 of 87600 time steps.
# Completed 62900 of 87600 time steps.
# Completed 63000 of 87600 time steps.
# Completed 63100 of 87600 time steps.
# Completed 63200 of 87600 time steps.
# Completed 63300 of 87600 time steps.
# Completed 63400 of 87600 time steps.
# Completed 63500 of 87600 time steps.
# Completed 63600 of 87600 time steps.
# Completed 63700 of 87600 time steps.
# Completed 63800 of 87600 time steps.
# Completed 63900 of 87600 time steps.
# Completed 64000 of 87600 time steps.
# Completed 64100 of 87600 time steps.
# Completed 64200 of 87600 time steps.
# Completed 64300 of 87600 time steps.
# Completed 64400 of 87600 time steps.
# Completed 64500 of 87600 time steps.
# Completed 64600 of 87600 time steps.
# Completed 64700 of 87600 time steps.
# Completed 64800 of 87600 time steps.
# Completed 64900 of 87600 time steps.
# Completed 65000 of 87600 time steps.
# Completed 65100 of 87600 time steps.
# Completed 65200 of 87600 time steps.
# Completed 65300 of 87600 time steps.
# Completed 65400 of 87600 time steps.
# Completed 65500 of 87600 time steps.
# Completed 65600 of 87600 time steps.
# Completed 65700 of 87600 time steps.
# Completed 65800 of 87600 time steps.
# Completed 65900 of 87600 time steps.
# Completed 66000 of 87600 time steps.
# Completed 66100 of 87600 time steps.
# Completed 66200 of 87600 time steps.
# Completed 66300 of 87600 time steps.
# Completed 66400 of 87600 time steps.
# Completed 66500 of 87600 time steps.
# Completed 66600 of 87600 time steps.
# Completed 66700 of 87600 time steps.
# Completed 66800 of 87600 time steps.
# Completed 66900 of 87600 time steps.
# Completed 67000 of 87600 time steps.
# Completed 67100 of 87600 time steps.
# Completed 67200 of 87600 time steps.
# Completed 67300 of 87600 time steps.
# Completed 67400 of 87600 time steps.
# Completed 67500 of 87600 time steps.
# Completed 67600 of 87600 time steps.
# Completed 67700 of 87600 time steps.
# Completed 67800 of 87600 time steps.
# Completed 67900 of 87600 time steps.
# Completed 68000 of 87600 time steps.
# Completed 68100 of 87600 time steps.
# Completed 68200 of 87600 time steps.
# Completed 68300 of 87600 time steps.
# Completed 68400 of 87600 time steps.
# Completed 68500 of 87600 time steps.
# Completed 68600 of 87600 time steps.
# Completed 68700 of 87600 time steps.
# Completed 68800 of 87600 time steps.
# Completed 68900 of 87600 time steps.
# Completed 69000 of 87600 time steps.
# Completed 69100 of 87600 time steps.
# Completed 69200 of 87600 time steps.
# Completed 69300 of 87600 time steps.
# Completed 69400 of 87600 time steps.
# Completed 69500 of 87600 time steps.
# Completed 69600 of 87600 time steps.
# Completed 69700 of 87600 time steps.
# Completed 69800 of 87600 time steps.
# Completed 69900 of 87600 time steps.
# Completed 70000 of 87600 time steps.
# Completed 70100 of 87600 time steps.
# Completed 70200 of 87600 time steps.
# Completed 70300 of 87600 time steps.
# Completed 70400 of 87600 time steps.
# Completed 70500 of 87600 time steps.
# Completed 70600 of 87600 time steps.
# Completed 70700 of 87600 time steps.
# Completed 70800 of 87600 time steps.
# Completed 70900 of 87600 time steps.
# Completed 71000 of 87600 time steps.
# Completed 71100 of 87600 time steps.
# Completed 71200 of 87600 time steps.
# Completed 71300 of 87600 time steps.
# Completed 71400 of 87600 time steps.
# Completed 71500 of 87600 time steps.
# Completed 71600 of 87600 time steps.
# Completed 71700 of 87600 time steps.
# Completed 71800 of 87600 time steps.
# Completed 71900 of 87600 time steps.
# Completed 72000 of 87600 time steps.
# Completed 72100 of 87600 time steps.
# Completed 72200 of 87600 time steps.
# Completed 72300 of 87600 time steps.
# Completed 72400 of 87600 time steps.
# Completed 72500 of 87600 time steps.
# Completed 72600 of 87600 time steps.
# Completed 72700 of 87600 time steps.
# Completed 72800 of 87600 time steps.
# Completed 72900 of 87600 time steps.
# Completed 73000 of 87600 time steps.
# Completed 73100 of 87600 time steps.
# Completed 73200 of 87600 time steps.
# Completed 73300 of 87600 time steps.
# Completed 73400 of 87600 time steps.
# Completed 73500 of 87600 time steps.
# Completed 73600 of 87600 time steps.
# Completed 73700 of 87600 time steps.
# Completed 73800 of 87600 time steps.
# Completed 73900 of 87600 time steps.
# Completed 74000 of 87600 time steps.
# Completed 74100 of 87600 time steps.
# Completed 74200 of 87600 time steps.
# Completed 74300 of 87600 time steps.
# Completed 74400 of 87600 time steps.
# Completed 74500 of 87600 time steps.
# Completed 74600 of 87600 time steps.
# Completed 74700 of 87600 time steps.
# Completed 74800 of 87600 time steps.
# Completed 74900 of 87600 time steps.
# Completed 75000 of 87600 time steps.
# Completed 75100 of 87600 time steps.
# Completed 75200 of 87600 time steps.
# Completed 75300 of 87600 time steps.
# Completed 75400 of 87600 time steps.
# Completed 75500 of 87600 time steps.
# Completed 75600 of 87600 time steps.
# Completed 75700 of 87600 time steps.
# Completed 75800 of 87600 time steps.
# Completed 75900 of 87600 time steps.
# Completed 76000 of 87600 time steps.
# Completed 76100 of 87600 time steps.
# Completed 76200 of 87600 time steps.
# Completed 76300 of 87600 time steps.
# Completed 76400 of 87600 time steps.
# Completed 76500 of 87600 time steps.
# Completed 76600 of 87600 time steps.
# Completed 76700 of 87600 time steps.
# Completed 76800 of 87600 time steps.
# Completed 76900 of 87600 time steps.
# Completed 77000 of 87600 time steps.
# Completed 77100 of 87600 time steps.
# Completed 77200 of 87600 time steps.
# Completed 77300 of 87600 time steps.
# Completed 77400 of 87600 time steps.
# Completed 77500 of 87600 time steps.
# Completed 77600 of 87600 time steps.
# Completed 77700 of 87600 time steps.
# Completed 77800 of 87600 time steps.
# Completed 77900 of 87600 time steps.
# Completed 78000 of 87600 time steps.
# Completed 78100 of 87600 time steps.
# Completed 78200 of 87600 time steps.
# Completed 78300 of 87600 time steps.
# Completed 78400 of 87600 time steps.
# Completed 78500 of 87600 time steps.
# Completed 78600 of 87600 time steps.
# Completed 78700 of 87600 time steps.
# Completed 78800 of 87600 time steps.
# Completed 78900 of 87600 time steps.
# Completed 79000 of 87600 time steps.
# Completed 79100 of 87600 time steps.
# Completed 79200 of 87600 time steps.
# Completed 79300 of 87600 time steps.
# Completed 79400 of 87600 time steps.
# Completed 79500 of 87600 time steps.
# Completed 79600 of 87600 time steps.
# Completed 79700 of 87600 time steps.
# Completed 79800 of 87600 time steps.
# Completed 79900 of 87600 time steps.
# Completed 80000 of 87600 time steps.
# Completed 80100 of 87600 time steps.
# Completed 80200 of 87600 time steps.
# Completed 80300 of 87600 time steps.
# Completed 80400 of 87600 time steps.
# Completed 80500 of 87600 time steps.
# Completed 80600 of 87600 time steps.
# Completed 80700 of 87600 time steps.
# Completed 80800 of 87600 time steps.
# Completed 80900 of 87600 time steps.
# Completed 81000 of 87600 time steps.
# Completed 81100 of 87600 time steps.
# Completed 81200 of 87600 time steps.
# Completed 81300 of 87600 time steps.
# Completed 81400 of 87600 time steps.
# Completed 81500 of 87600 time steps.
# Completed 81600 of 87600 time steps.
# Completed 81700 of 87600 time steps.
# Completed 81800 of 87600 time steps.
# Completed 81900 of 87600 time steps.
# Completed 82000 of 87600 time steps.
# Completed 82100 of 87600 time steps.
# Completed 82200 of 87600 time steps.
# Completed 82300 of 87600 time steps.
# Completed 82400 of 87600 time steps.
# Completed 82500 of 87600 time steps.
# Completed 82600 of 87600 time steps.
# Completed 82700 of 87600 time steps.
# Completed 82800 of 87600 time steps.
# Completed 82900 of 87600 time steps.
# Completed 83000 of 87600 time steps.
# Completed 83100 of 87600 time steps.
# Completed 83200 of 87600 time steps.
# Completed 83300 of 87600 time steps.
# Completed 83400 of 87600 time steps.
# Completed 83500 of 87600 time steps.
# Completed 83600 of 87600 time steps.
# Completed 83700 of 87600 time steps.
# Completed 83800 of 87600 time steps.
# Completed 83900 of 87600 time steps.
# Completed 84000 of 87600 time steps.
# Completed 84100 of 87600 time steps.
# Completed 84200 of 87600 time steps.
# Completed 84300 of 87600 time steps.
# Completed 84400 of 87600 time steps.
# Completed 84500 of 87600 time steps.
# Completed 84600 of 87600 time steps.
# Completed 84700 of 87600 time steps.
# Completed 84800 of 87600 time steps.
# Completed 84900 of 87600 time steps.
# Completed 85000 of 87600 time steps.
# Completed 85100 of 87600 time steps.
# Completed 85200 of 87600 time steps.
# Completed 85300 of 87600 time steps.
# Completed 85400 of 87600 time steps.
# Completed 85500 of 87600 time steps.
# Completed 85600 of 87600 time steps.
# Completed 85700 of 87600 time steps.
# Completed 85800 of 87600 time steps.
# Completed 85900 of 87600 time steps.
# Completed 86000 of 87600 time steps.
# Completed 86100 of 87600 time steps.
# Completed 86200 of 87600 time steps.
# Completed 86300 of 87600 time steps.
# Completed 86400 of 87600 time steps.
# Completed 86500 of 87600 time steps.
# Completed 86600 of 87600 time steps.
# Completed 86700 of 87600 time steps.
# Completed 86800 of 87600 time steps.
# Completed 86900 of 87600 time steps.
# Completed 87000 of 87600 time steps.
# Completed 87100 of 87600 time steps.
# Completed 87200 of 87600 time steps.
# Completed 87300 of 87600 time steps.
# Completed 87400 of 87600 time steps.
# Completed 87500 of 87600 time steps.
# Completed 87600 of 87600 time steps.
# Simulation end. Elapsed time: 1457.48 seconds.

# %% [markdown]
# Plot results.

# %%
# Plot fluid temperatures during last year
fig, ax = plt.subplots(layout='constrained')

ax = gs.plot._format_axis(ax, axis_labels=[r'$t$ [h]', r'$T_{f,in}, T_{f,out}$ [℃]'])
time = jnp.arange(simulation.n_times) - 9 * 8760
ax.plot(time, simulation.T_f_in, '-', label='Inlet');
ax.plot(time, simulation.T_f_out, '--', label='Outlet');
ax.legend(frameon=False)
fig.set_size_inches(90. / 25.4, 90. / 25.4)
ax.set_xlim(0, 8760)
fig.savefig('last-year-KTH.eps')

# %%
# Plot simulation results during peak of last year
fig, axs = plt.subplots(nrows=3, layout='constrained', sharex=True)
time = jnp.arange(simulation.n_times) - 9 * 8760

axs[0] = gs.plot._format_axis(axs[0], axis_labels=[None, r'$\bar{q}^\prime$ [W/m]'])
axs[0].plot(time, simulation.Q / borefield.L.sum(), '-');

axs[1] = gs.plot._format_axis(axs[1], axis_labels=[None, r'$\dot{m}_{f}$ [kg/s]'])
axs[1].plot(time, simulation.m_flow / len(paths), '-');

axs[2] = gs.plot._format_axis(axs[2], axis_labels=[r'$t$ [h]', r'$T_{f,in}, T_{f,out}$ [℃]'])
axs[2].plot(time, simulation.T_f_in, '-', label='Inlet');
axs[2].plot(time, simulation.T_f_out, '--', label='Outlet');
axs[2].legend(frameon=False, ncols=2, loc=4)
fig.set_size_inches(140. / 25.4, 90. / 25.4)
axs[2].set_xlim(177 * 24, 184 * 24)
fig.savefig('peak-week-KTH.eps')
