# %% [markdown]
# # 3. Field of 8 inclined boreholes with straight trajectories : (b) Convergence of geothermsim with regards to the discretization
# The convergence of the model is evaluated by comparison with a solution obtained with a fine discretization.

# %%
# Import necessary packages
# Import packages for geothermsim
import geothermsim as gs
from jax import numpy as jnp

# Import packages for visualization
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ### 3(b).1. Simulation parameters

# %%
# Borehole dimensions
D = 2.0             # Borehole buried depth (m)
L = 150.0           # Borehole length (m)
r_b = 0.075         # Borehole radius (m)
# Borehole spacings (m), tilt (deg), and inclinations (deg)
B = L * 0.025
tilt = jnp.radians(20.)
orientation = jnp.radians(jnp.array([180., 135., -135., 90., -90., 45., -45, 0.]))

# Pipe dimensions
r_out = 0.0211      # Pipe outer radius (m)
r_in = 0.0147       # Pipe inner radius (m)
D_s = 0.052         # Shank spacing (m)
epsilon = 2.12e-5   # Pipe roughness (m)

# Pipe positions
# Single U-tube : [[x_in, y_in], [x_out, y_out]]
p_pipes = jnp.array([[-D_s, 0.], [D_s, 0.]])

# Ground properties
alpha = 1.0e-6      # Ground thermal diffusivity (m2/s)
k_s = 2.0           # Ground thermal conductivity (W/m.K)

# Grout properties
k_b = 1.0           # Grout thermal conductivity (W/m.K)

# Pipe properties
k_p = 0.4           # Pipe thermal conductivity (W/m.K)

# Fluid properties
m_flow_borehole = 0.375 # Total fluid mass flow rate per borehole (kg/s)
m_flow_network = m_flow_borehole * len(orientation)
# The fluid is propylene-glycol (20 %) at 20 degC
cp_f = 3976.8       # Fluid specific heat capacity (in J/kg-K)
rho_f = 1014.8      # Fluid density (kg/m3)
mu_f = 2.0301e-3    # Fluid dynamic viscosity (kg/m.s)
k_f = 0.49221       # Fluid thermal conductivity (W/m.K)

# %% [markdown]
# The convergence of the solution is evaluated near steady-state, at $\ln(t/t_s)=5$.

# %%
ts = L**2 / (9 * alpha)    # Bore field characteristic time
lntts = jnp.array([5.])
time = jnp.exp(lntts) * ts

# %% [markdown]
# ## 3(b).2. Reference solution
# The reference solution is evaluated using $S=20$ segments of $N=11$ nodes (220 nodes in total).

# %%
N_ref = 11
S_ref = 20

basis = gs.Basis.Legendre(N_ref)
ground_heat_exchanger = gs.UTubeHeatExchanger(
    p_pipes, r_in, r_out, r_b, k_s, k_b, k_p, mu_f, rho_f, k_f, cp_f, epsilon)
R_d = ground_heat_exchanger.thermal_resistances
boreholes = []
for i, _orientation in enumerate(orientation):
    boreholes.append(
        gs.SingleUTube.from_dimensions(
            R_d, L, D, r_b, i * B, 0., basis, S_ref, tilt=tilt, orientation=_orientation))
borefield_reference = gs.Network(boreholes)

# %% [markdown]
# The `gFunction` object is initialized and the $g$-function is evaluated.

# %%
gfunc_reference = gs.gFunction(borefield_reference, m_flow_network, cp_f, time, alpha, k_s)
gfunc_reference.simulate()
# Out:
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.21 seconds.
# Initialization end. Elapsed time: 2.23 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.23 seconds.

# %% [markdown]
# ## 3(b).3. Convergence of geothermsim
# The solution is evaluated for numbers of segments ranging from $1$ to $5$ and for numbers of nodes per segment ranging from $1$ to $11$.
#
# The `Borefield` objects are first initialized for each discretization.

# %%
N_max = 11
S_max = 5
n = 0

borefields = []
for _S in range(1, S_max + 1):
    for _N in range(1, N_max + 1):
        basis = gs.Basis.Legendre(_N)
        boreholes = []
        for i, _orientation in enumerate(orientation):
            boreholes.append(
                gs.SingleUTube.from_dimensions(
                    R_d, L, D, r_b, i * B, 0., basis, _S, tilt=tilt, orientation=_orientation))
        borefields.append(gs.Network(boreholes))

# %% [markdown]
# The $g$-functions are then evaluated.

# %%
gfunc = [gs.gFunction(borefield, m_flow_network, cp_f, time, alpha, k_s) for borefield in borefields]
# Out:
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.13 seconds.
# Initialization end. Elapsed time: 2.14 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.03 seconds.
# Initialization end. Elapsed time: 2.04 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.04 seconds.
# Initialization end. Elapsed time: 2.06 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.05 seconds.
# Initialization end. Elapsed time: 2.06 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.07 seconds.
# Initialization end. Elapsed time: 2.08 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.12 seconds.
# Initialization end. Elapsed time: 2.14 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.15 seconds.
# Initialization end. Elapsed time: 2.17 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.48 seconds.
# Initialization end. Elapsed time: 2.50 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.10 seconds.
# Initialization end. Elapsed time: 2.11 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.16 seconds.
# Initialization end. Elapsed time: 2.18 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.44 seconds.
# Initialization end. Elapsed time: 2.45 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.47 seconds.
# Initialization end. Elapsed time: 1.47 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.28 seconds.
# Initialization end. Elapsed time: 1.28 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.35 seconds.
# Initialization end. Elapsed time: 1.35 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.36 seconds.
# Initialization end. Elapsed time: 1.36 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.80 seconds.
# Initialization end. Elapsed time: 1.80 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.16 seconds.
# Initialization end. Elapsed time: 2.17 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.18 seconds.
# Initialization end. Elapsed time: 2.20 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.26 seconds.
# Initialization end. Elapsed time: 2.28 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.27 seconds.
# Initialization end. Elapsed time: 2.29 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.20 seconds.
# Initialization end. Elapsed time: 2.22 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.31 seconds.
# Initialization end. Elapsed time: 2.32 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.49 seconds.
# Initialization end. Elapsed time: 1.49 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.32 seconds.
# Initialization end. Elapsed time: 1.32 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.98 seconds.
# Initialization end. Elapsed time: 1.98 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.33 seconds.
# Initialization end. Elapsed time: 1.33 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.13 seconds.
# Initialization end. Elapsed time: 2.14 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.31 seconds.
# Initialization end. Elapsed time: 1.31 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.19 seconds.
# Initialization end. Elapsed time: 2.20 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.27 seconds.
# Initialization end. Elapsed time: 2.29 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.64 seconds.
# Initialization end. Elapsed time: 2.66 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.34 seconds.
# Initialization end. Elapsed time: 2.35 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.45 seconds.
# Initialization end. Elapsed time: 2.46 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.46 seconds.
# Initialization end. Elapsed time: 1.46 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.37 seconds.
# Initialization end. Elapsed time: 1.37 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.36 seconds.
# Initialization end. Elapsed time: 1.36 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.41 seconds.
# Initialization end. Elapsed time: 1.41 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.31 seconds.
# Initialization end. Elapsed time: 1.31 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.35 seconds.
# Initialization end. Elapsed time: 1.35 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.17 seconds.
# Initialization end. Elapsed time: 2.18 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.29 seconds.
# Initialization end. Elapsed time: 2.31 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.39 seconds.
# Initialization end. Elapsed time: 2.40 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.39 seconds.
# Initialization end. Elapsed time: 2.41 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.50 seconds.
# Initialization end. Elapsed time: 2.51 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.51 seconds.
# Initialization end. Elapsed time: 1.51 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.30 seconds.
# Initialization end. Elapsed time: 1.30 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.10 seconds.
# Initialization end. Elapsed time: 2.10 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.39 seconds.
# Initialization end. Elapsed time: 1.39 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.24 seconds.
# Initialization end. Elapsed time: 2.26 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.38 seconds.
# Initialization end. Elapsed time: 1.38 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.71 seconds.
# Initialization end. Elapsed time: 2.72 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.34 seconds.
# Initialization end. Elapsed time: 1.34 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.45 seconds.
# Initialization end. Elapsed time: 2.46 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.19 seconds.
# Initialization end. Elapsed time: 2.20 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.44 seconds.
# Initialization end. Elapsed time: 2.46 seconds.

# %%
for _gfunc in gfunc:
    _gfunc.simulate()
values = jnp.array([_gfunc.g[-1] for _gfunc in gfunc]).reshape(S_max, N_max).T
# Out:
# Simulation start.
# Simulation end. Elapsed time: 0.62 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.49 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.50 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.57 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.53 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.47 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.47 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.44 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.49 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.49 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.48 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.52 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.42 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.38 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.39 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.41 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.50 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.47 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.49 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.46 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.48 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.47 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.57 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.42 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.38 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.39 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.47 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.39 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.47 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.47 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.51 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.48 seconds.
# Simulation start.
# Simulation end. Elapsed time: 1.44 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.58 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.39 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.39 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.39 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.40 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.43 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.49 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.49 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.49 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.50 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.52 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.48 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.41 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.40 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.42 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.50 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.43 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.51 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.43 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.50 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.53 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.57 seconds.

# %%
# Format and print dataframe
df = pd.DataFrame(
    values,
    columns=[f'S = {_S}' for _S in jnp.arange(1, S_max + 1)],
    index=jnp.arange(1, N_max + 1))
df.index.name = 'N'
df.style.set_caption(r'$g$-Function at $ln(t/t_s)=5$')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e9226">
#   <caption>$g$-Function at $ln(t/t_s)=5$</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9226_level0_col0" class="col_heading level0 col0" >S = 1</th>
#       <th id="T_e9226_level0_col1" class="col_heading level0 col1" >S = 2</th>
#       <th id="T_e9226_level0_col2" class="col_heading level0 col2" >S = 3</th>
#       <th id="T_e9226_level0_col3" class="col_heading level0 col3" >S = 4</th>
#       <th id="T_e9226_level0_col4" class="col_heading level0 col4" >S = 5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >N</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9226_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e9226_row0_col0" class="data row0 col0" >12.877833</td>
#       <td id="T_e9226_row0_col1" class="data row0 col1" >12.298955</td>
#       <td id="T_e9226_row0_col2" class="data row0 col2" >12.080682</td>
#       <td id="T_e9226_row0_col3" class="data row0 col3" >11.957511</td>
#       <td id="T_e9226_row0_col4" class="data row0 col4" >11.875598</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e9226_row1_col0" class="data row1 col0" >12.084943</td>
#       <td id="T_e9226_row1_col1" class="data row1 col1" >11.808656</td>
#       <td id="T_e9226_row1_col2" class="data row1 col2" >11.708848</td>
#       <td id="T_e9226_row1_col3" class="data row1 col3" >11.656533</td>
#       <td id="T_e9226_row1_col4" class="data row1 col4" >11.623462</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e9226_row2_col0" class="data row2 col0" >11.811349</td>
#       <td id="T_e9226_row2_col1" class="data row2 col1" >11.657575</td>
#       <td id="T_e9226_row2_col2" class="data row2 col2" >11.603547</td>
#       <td id="T_e9226_row2_col3" class="data row2 col3" >11.574363</td>
#       <td id="T_e9226_row2_col4" class="data row2 col4" >11.557353</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e9226_row3_col0" class="data row3 col0" >11.688233</td>
#       <td id="T_e9226_row3_col1" class="data row3 col1" >11.591563</td>
#       <td id="T_e9226_row3_col2" class="data row3 col2" >11.557904</td>
#       <td id="T_e9226_row3_col3" class="data row3 col3" >11.542291</td>
#       <td id="T_e9226_row3_col4" class="data row3 col4" >11.534640</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e9226_row4_col0" class="data row4 col0" >11.622018</td>
#       <td id="T_e9226_row4_col1" class="data row4 col1" >11.558984</td>
#       <td id="T_e9226_row4_col2" class="data row4 col2" >11.538388</td>
#       <td id="T_e9226_row4_col3" class="data row4 col3" >11.530087</td>
#       <td id="T_e9226_row4_col4" class="data row4 col4" >11.525996</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e9226_row5_col0" class="data row5 col0" >11.584895</td>
#       <td id="T_e9226_row5_col1" class="data row5 col1" >11.541696</td>
#       <td id="T_e9226_row5_col2" class="data row5 col2" >11.528890</td>
#       <td id="T_e9226_row5_col3" class="data row5 col3" >11.523879</td>
#       <td id="T_e9226_row5_col4" class="data row5 col4" >11.521098</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e9226_row6_col0" class="data row6 col0" >11.562263</td>
#       <td id="T_e9226_row6_col1" class="data row6 col1" >11.532401</td>
#       <td id="T_e9226_row6_col2" class="data row6 col2" >11.523681</td>
#       <td id="T_e9226_row6_col3" class="data row6 col3" >11.520171</td>
#       <td id="T_e9226_row6_col4" class="data row6 col4" >11.517924</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_e9226_row7_col0" class="data row7 col0" >11.548526</td>
#       <td id="T_e9226_row7_col1" class="data row7 col1" >11.526517</td>
#       <td id="T_e9226_row7_col2" class="data row7 col2" >11.520219</td>
#       <td id="T_e9226_row7_col3" class="data row7 col3" >11.517499</td>
#       <td id="T_e9226_row7_col4" class="data row7 col4" >11.515517</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_e9226_row8_col0" class="data row8 col0" >11.539783</td>
#       <td id="T_e9226_row8_col1" class="data row8 col1" >11.522624</td>
#       <td id="T_e9226_row8_col2" class="data row8 col2" >11.517861</td>
#       <td id="T_e9226_row8_col3" class="data row8 col3" >11.515521</td>
#       <td id="T_e9226_row8_col4" class="data row8 col4" >11.513688</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_e9226_row9_col0" class="data row9 col0" >11.533912</td>
#       <td id="T_e9226_row9_col1" class="data row9 col1" >11.519752</td>
#       <td id="T_e9226_row9_col2" class="data row9 col2" >11.516030</td>
#       <td id="T_e9226_row9_col3" class="data row9 col3" >11.513902</td>
#       <td id="T_e9226_row9_col4" class="data row9 col4" >11.512202</td>
#     </tr>
#     <tr>
#       <th id="T_e9226_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_e9226_row10_col0" class="data row10 col0" >11.529693</td>
#       <td id="T_e9226_row10_col1" class="data row10 col1" >11.517737</td>
#       <td id="T_e9226_row10_col2" class="data row10 col2" >11.514697</td>
#       <td id="T_e9226_row10_col3" class="data row10 col3" >11.512666</td>
#       <td id="T_e9226_row10_col4" class="data row10 col4" >11.511144</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The relative error is calculated from the difference between the solution and the reference:
# $$
# \varepsilon_{rel} = \frac{g - g_{ref}}{g_{ref}}
# $$

# %%
error = (jnp.array([_gfunc.g[-1] for _gfunc in gfunc]).reshape(S_max, N_max).T - gfunc_reference.g[-1]) / gfunc_reference.g[-1]

# %%
# Format and print dataframe
df = pd.DataFrame(
    error,
    columns=[f'S = {_S}' for _S in jnp.arange(1, S_max + 1)],
    index=jnp.arange(1, N_max + 1))
df.index.name = 'N'
df.style.set_caption(r'Relative error on the $g$-function at $ln(t/t_s)=5$')
# Out:
# <style type="text/css">
# </style>
# <table id="T_79d86">
#   <caption>Relative error on the $g$-function at $ln(t/t_s)=5$</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79d86_level0_col0" class="col_heading level0 col0" >S = 1</th>
#       <th id="T_79d86_level0_col1" class="col_heading level0 col1" >S = 2</th>
#       <th id="T_79d86_level0_col2" class="col_heading level0 col2" >S = 3</th>
#       <th id="T_79d86_level0_col3" class="col_heading level0 col3" >S = 4</th>
#       <th id="T_79d86_level0_col4" class="col_heading level0 col4" >S = 5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >N</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79d86_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_79d86_row0_col0" class="data row0 col0" >0.119109</td>
#       <td id="T_79d86_row0_col1" class="data row0 col1" >0.068803</td>
#       <td id="T_79d86_row0_col2" class="data row0 col2" >0.049835</td>
#       <td id="T_79d86_row0_col3" class="data row0 col3" >0.039131</td>
#       <td id="T_79d86_row0_col4" class="data row0 col4" >0.032012</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_79d86_row1_col0" class="data row1 col0" >0.050205</td>
#       <td id="T_79d86_row1_col1" class="data row1 col1" >0.026195</td>
#       <td id="T_79d86_row1_col2" class="data row1 col2" >0.017522</td>
#       <td id="T_79d86_row1_col3" class="data row1 col3" >0.012975</td>
#       <td id="T_79d86_row1_col4" class="data row1 col4" >0.010101</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_79d86_row2_col0" class="data row2 col0" >0.026429</td>
#       <td id="T_79d86_row2_col1" class="data row2 col1" >0.013066</td>
#       <td id="T_79d86_row2_col2" class="data row2 col2" >0.008371</td>
#       <td id="T_79d86_row2_col3" class="data row2 col3" >0.005834</td>
#       <td id="T_79d86_row2_col4" class="data row2 col4" >0.004356</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_79d86_row3_col0" class="data row3 col0" >0.015730</td>
#       <td id="T_79d86_row3_col1" class="data row3 col1" >0.007329</td>
#       <td id="T_79d86_row3_col2" class="data row3 col2" >0.004404</td>
#       <td id="T_79d86_row3_col3" class="data row3 col3" >0.003047</td>
#       <td id="T_79d86_row3_col4" class="data row3 col4" >0.002383</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_79d86_row4_col0" class="data row4 col0" >0.009976</td>
#       <td id="T_79d86_row4_col1" class="data row4 col1" >0.004498</td>
#       <td id="T_79d86_row4_col2" class="data row4 col2" >0.002708</td>
#       <td id="T_79d86_row4_col3" class="data row4 col3" >0.001987</td>
#       <td id="T_79d86_row4_col4" class="data row4 col4" >0.001631</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_79d86_row5_col0" class="data row5 col0" >0.006750</td>
#       <td id="T_79d86_row5_col1" class="data row5 col1" >0.002996</td>
#       <td id="T_79d86_row5_col2" class="data row5 col2" >0.001883</td>
#       <td id="T_79d86_row5_col3" class="data row5 col3" >0.001447</td>
#       <td id="T_79d86_row5_col4" class="data row5 col4" >0.001206</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_79d86_row6_col0" class="data row6 col0" >0.004783</td>
#       <td id="T_79d86_row6_col1" class="data row6 col1" >0.002188</td>
#       <td id="T_79d86_row6_col2" class="data row6 col2" >0.001430</td>
#       <td id="T_79d86_row6_col3" class="data row6 col3" >0.001125</td>
#       <td id="T_79d86_row6_col4" class="data row6 col4" >0.000930</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_79d86_row7_col0" class="data row7 col0" >0.003589</td>
#       <td id="T_79d86_row7_col1" class="data row7 col1" >0.001677</td>
#       <td id="T_79d86_row7_col2" class="data row7 col2" >0.001129</td>
#       <td id="T_79d86_row7_col3" class="data row7 col3" >0.000893</td>
#       <td id="T_79d86_row7_col4" class="data row7 col4" >0.000721</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_79d86_row8_col0" class="data row8 col0" >0.002829</td>
#       <td id="T_79d86_row8_col1" class="data row8 col1" >0.001338</td>
#       <td id="T_79d86_row8_col2" class="data row8 col2" >0.000924</td>
#       <td id="T_79d86_row8_col3" class="data row8 col3" >0.000721</td>
#       <td id="T_79d86_row8_col4" class="data row8 col4" >0.000562</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_79d86_row9_col0" class="data row9 col0" >0.002319</td>
#       <td id="T_79d86_row9_col1" class="data row9 col1" >0.001089</td>
#       <td id="T_79d86_row9_col2" class="data row9 col2" >0.000765</td>
#       <td id="T_79d86_row9_col3" class="data row9 col3" >0.000580</td>
#       <td id="T_79d86_row9_col4" class="data row9 col4" >0.000433</td>
#     </tr>
#     <tr>
#       <th id="T_79d86_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_79d86_row10_col0" class="data row10 col0" >0.001953</td>
#       <td id="T_79d86_row10_col1" class="data row10 col1" >0.000914</td>
#       <td id="T_79d86_row10_col2" class="data row10 col2" >0.000649</td>
#       <td id="T_79d86_row10_col3" class="data row10 col3" >0.000473</td>
#       <td id="T_79d86_row10_col4" class="data row10 col4" >0.000341</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plot error as function of N and S
fig, axs = plt.subplots(ncols=2, sharey=True, layout='constrained')

N = jnp.arange(1, N_max + 1)
S = jnp.arange(1, S_max + 1)

axs[0].set_xscale('function', functions=(lambda x: jnp.log(x), lambda x: jnp.exp(x)))
axs[0] = gs.plot._format_axis(axs[0], axis_labels=[r'$N$', r'$log_{10}(\varepsilon_{rel})$'])
axs[0].plot(N, jnp.log10(error), '-o');
axs[0].plot(N, jnp.log10(0.1 / N**2), 'k--');
axs[0].legend([f'$S={_S}$' for _S in S] + [r'$1 / N^2$'], frameon=False)

axs[1].set_xscale('function', functions=(lambda x: jnp.log(x), lambda x: jnp.exp(x)))
axs[1] = gs.plot._format_axis(axs[1])
axs[1].set_xlabel(r'S')
axs[1].plot(S, jnp.log10(error.T), '-o');
axs[1].plot(S, jnp.log10(0.01 / S), 'k--');
axs[1].set_xlim(None, 20)
axs[1].legend([f'$N={_N}$' for _N in N] + [r'$1 / S$'], frameon=False)

fig.set_size_inches(140. / 25.4, 90. / 25.4)
fig.savefig('convergence-Eskilson-optimal.eps')
