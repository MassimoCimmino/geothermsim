# %% [markdown]
# # 3. Field of 8 inclined boreholes with straight trajectories : (b) Convergence of geothermsim with regards to the discretization
# The convergence of the model is evaluated by comparison with a solution obtained with a fine discretization.

# %%
# Import necessary packages
# Import packages for geothermsim
import geothermsim as gs
from jax import numpy as jnp

# Import packages for visualization
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ### 3(b).1. Simulation parameters

# %%
# Borehole dimensions
D = 2.0             # Borehole buried depth (m)
L = 150.0           # Borehole length (m)
r_b = 0.075         # Borehole radius (m)
# Borehole spacings (m), tilt (deg), and inclinations (deg)
B = L * 0.025
tilt = jnp.radians(20.)
orientation = jnp.radians(jnp.array([180., 135., -135., 90., -90., 45., -45, 0.]))

# Pipe dimensions
r_out = 0.0211      # Pipe outer radius (m)
r_in = 0.0147       # Pipe inner radius (m)
D_s = 0.052         # Shank spacing (m)
epsilon = 2.12e-5   # Pipe roughness (m)

# Pipe positions
# Single U-tube : [[x_in, y_in], [x_out, y_out]]
p_pipes = jnp.array([[-D_s, 0.], [D_s, 0.]])

# Ground properties
alpha = 1.0e-6      # Ground thermal diffusivity (m2/s)
k_s = 2.0           # Ground thermal conductivity (W/m.K)

# Grout properties
k_b = 1.0           # Grout thermal conductivity (W/m.K)

# Pipe properties
k_p = 0.4           # Pipe thermal conductivity (W/m.K)

# Fluid properties
m_flow_borehole = 0.375 # Total fluid mass flow rate per borehole (kg/s)
m_flow_network = m_flow_borehole * len(orientation)
# The fluid is propylene-glycol (20 %) at 20 degC
T_nominal = 20.
fluid = gs.Fluid.from_scp(
    'PropyleneGlycol', T_nominal, x=0.2
)

# %% [markdown]
# The convergence of the solution is evaluated near steady-state, at $\ln(t/t_s)=5$.

# %%
ts = L**2 / (9 * alpha)    # Bore field characteristic time
lntts = jnp.array([5.])
time = jnp.exp(lntts) * ts

# %% [markdown]
# ## 3(b).2. Reference solution
# The reference solution is evaluated using $S=20$ segments of $N=11$ nodes (220 nodes in total).

# %%
N_ref = 11
S_ref = 20

basis = gs.Basis.Legendre(N_ref)
ground_heat_exchanger = gs.UTubeHeatExchanger(
    p_pipes, r_in, r_out, r_b, fluid, k_s, k_b, k_p, epsilon)
R_d = ground_heat_exchanger.thermal_resistances
boreholes = []
for i, _orientation in enumerate(orientation):
    boreholes.append(
        gs.SingleUTube.from_dimensions(
            R_d, fluid, L, D, r_b, i * B, 0., basis, S_ref, tilt=tilt, orientation=_orientation))
borefield_reference = gs.Network(boreholes, fluid)

# %% [markdown]
# The `gFunction` object is initialized and the $g$-function is evaluated.

# %%
gfunc_reference = gs.gFunction(borefield_reference, m_flow_network, time, alpha, k_s)
gfunc_reference.simulate()
# Out:
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.50 seconds.
# Initialization end. Elapsed time: 2.52 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.52 seconds.

# %% [markdown]
# ## 3(b).3. Convergence of geothermsim
# The solution is evaluated for numbers of segments ranging from $1$ to $5$ and for numbers of nodes per segment ranging from $1$ to $11$.
#
# The `Borefield` objects are first initialized for each discretization.

# %%
N_max = 11
S_max = 5
n = 0

borefields = []
for _S in range(1, S_max + 1):
    for _N in range(1, N_max + 1):
        basis = gs.Basis.Legendre(_N)
        boreholes = []
        for i, _orientation in enumerate(orientation):
            boreholes.append(
                gs.SingleUTube.from_dimensions(
                    R_d, fluid, L, D, r_b, i * B, 0., basis, _S, tilt=tilt, orientation=_orientation))
        borefields.append(gs.Network(boreholes, fluid))

# %% [markdown]
# The $g$-functions are then evaluated.

# %%
gfunc = [gs.gFunction(borefield, m_flow_network, time, alpha, k_s) for borefield in borefields]
# Out:
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.13 seconds.
# Initialization end. Elapsed time: 2.15 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.17 seconds.
# Initialization end. Elapsed time: 2.18 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.18 seconds.
# Initialization end. Elapsed time: 2.20 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.21 seconds.
# Initialization end. Elapsed time: 2.23 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.53 seconds.
# Initialization end. Elapsed time: 2.55 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.35 seconds.
# Initialization end. Elapsed time: 2.38 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.53 seconds.
# Initialization end. Elapsed time: 2.55 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.94 seconds.
# Initialization end. Elapsed time: 2.95 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.61 seconds.
# Initialization end. Elapsed time: 2.63 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.55 seconds.
# Initialization end. Elapsed time: 2.57 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.70 seconds.
# Initialization end. Elapsed time: 2.72 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.48 seconds.
# Initialization end. Elapsed time: 1.48 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.30 seconds.
# Initialization end. Elapsed time: 1.30 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.35 seconds.
# Initialization end. Elapsed time: 1.35 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.40 seconds.
# Initialization end. Elapsed time: 1.40 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.38 seconds.
# Initialization end. Elapsed time: 1.38 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.55 seconds.
# Initialization end. Elapsed time: 2.56 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.79 seconds.
# Initialization end. Elapsed time: 2.82 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.52 seconds.
# Initialization end. Elapsed time: 2.54 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.69 seconds.
# Initialization end. Elapsed time: 2.70 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.54 seconds.
# Initialization end. Elapsed time: 2.56 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.72 seconds.
# Initialization end. Elapsed time: 2.73 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.61 seconds.
# Initialization end. Elapsed time: 1.61 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.62 seconds.
# Initialization end. Elapsed time: 1.62 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.52 seconds.
# Initialization end. Elapsed time: 1.52 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.63 seconds.
# Initialization end. Elapsed time: 1.63 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.54 seconds.
# Initialization end. Elapsed time: 2.55 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.48 seconds.
# Initialization end. Elapsed time: 1.48 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.66 seconds.
# Initialization end. Elapsed time: 2.68 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.77 seconds.
# Initialization end. Elapsed time: 2.78 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.07 seconds.
# Initialization end. Elapsed time: 3.09 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.71 seconds.
# Initialization end. Elapsed time: 2.73 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.32 seconds.
# Initialization end. Elapsed time: 3.34 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.90 seconds.
# Initialization end. Elapsed time: 1.90 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.53 seconds.
# Initialization end. Elapsed time: 1.53 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.33 seconds.
# Initialization end. Elapsed time: 2.33 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.68 seconds.
# Initialization end. Elapsed time: 1.68 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.74 seconds.
# Initialization end. Elapsed time: 1.74 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.55 seconds.
# Initialization end. Elapsed time: 1.55 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.75 seconds.
# Initialization end. Elapsed time: 2.78 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.72 seconds.
# Initialization end. Elapsed time: 2.74 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.63 seconds.
# Initialization end. Elapsed time: 3.65 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.94 seconds.
# Initialization end. Elapsed time: 2.96 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.08 seconds.
# Initialization end. Elapsed time: 3.10 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.77 seconds.
# Initialization end. Elapsed time: 1.77 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.55 seconds.
# Initialization end. Elapsed time: 1.55 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.66 seconds.
# Initialization end. Elapsed time: 1.66 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.71 seconds.
# Initialization end. Elapsed time: 1.71 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.69 seconds.
# Initialization end. Elapsed time: 2.71 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.59 seconds.
# Initialization end. Elapsed time: 1.59 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.05 seconds.
# Initialization end. Elapsed time: 3.07 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 1.80 seconds.
# Initialization end. Elapsed time: 1.80 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.18 seconds.
# Initialization end. Elapsed time: 3.21 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.68 seconds.
# Initialization end. Elapsed time: 3.70 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.89 seconds.
# Initialization end. Elapsed time: 2.90 seconds.

# %%
for _gfunc in gfunc:
    _gfunc.simulate()
values = jnp.array([_gfunc.g[-1] for _gfunc in gfunc]).reshape(S_max, N_max).T
# Out:
# Simulation start.
# Simulation end. Elapsed time: 0.72 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.60 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.63 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.64 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.62 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.69 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.58 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.54 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.67 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.77 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.75 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.69 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.57 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.55 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.49 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.58 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.68 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.58 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.57 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.62 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.57 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.72 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.70 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.60 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.50 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.62 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.65 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.58 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.79 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.64 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.71 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.61 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.68 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.70 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.54 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.58 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.53 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.53 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.63 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.62 seconds.
# Simulation start.
# Simulation end. Elapsed time: 1.62 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.61 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.63 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.64 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.59 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.50 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.45 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.52 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.65 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.52 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.66 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.60 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.57 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.74 seconds.
# Simulation start.
# Simulation end. Elapsed time: 0.68 seconds.

# %%
# Format and print dataframe
df = pd.DataFrame(
    values,
    columns=[f'S = {_S}' for _S in jnp.arange(1, S_max + 1)],
    index=jnp.arange(1, N_max + 1))
df.index.name = 'N'
df.style.set_caption(r'$g$-Function at $ln(t/t_s)=5$')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea280">
#   <caption>$g$-Function at $ln(t/t_s)=5$</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea280_level0_col0" class="col_heading level0 col0" >S = 1</th>
#       <th id="T_ea280_level0_col1" class="col_heading level0 col1" >S = 2</th>
#       <th id="T_ea280_level0_col2" class="col_heading level0 col2" >S = 3</th>
#       <th id="T_ea280_level0_col3" class="col_heading level0 col3" >S = 4</th>
#       <th id="T_ea280_level0_col4" class="col_heading level0 col4" >S = 5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >N</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea280_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ea280_row0_col0" class="data row0 col0" >12.877832</td>
#       <td id="T_ea280_row0_col1" class="data row0 col1" >12.298958</td>
#       <td id="T_ea280_row0_col2" class="data row0 col2" >12.080681</td>
#       <td id="T_ea280_row0_col3" class="data row0 col3" >11.957506</td>
#       <td id="T_ea280_row0_col4" class="data row0 col4" >11.875603</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ea280_row1_col0" class="data row1 col0" >12.084944</td>
#       <td id="T_ea280_row1_col1" class="data row1 col1" >11.808651</td>
#       <td id="T_ea280_row1_col2" class="data row1 col2" >11.708843</td>
#       <td id="T_ea280_row1_col3" class="data row1 col3" >11.656532</td>
#       <td id="T_ea280_row1_col4" class="data row1 col4" >11.623465</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ea280_row2_col0" class="data row2 col0" >11.811356</td>
#       <td id="T_ea280_row2_col1" class="data row2 col1" >11.657574</td>
#       <td id="T_ea280_row2_col2" class="data row2 col2" >11.603552</td>
#       <td id="T_ea280_row2_col3" class="data row2 col3" >11.574358</td>
#       <td id="T_ea280_row2_col4" class="data row2 col4" >11.557350</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ea280_row3_col0" class="data row3 col0" >11.688236</td>
#       <td id="T_ea280_row3_col1" class="data row3 col1" >11.591558</td>
#       <td id="T_ea280_row3_col2" class="data row3 col2" >11.557901</td>
#       <td id="T_ea280_row3_col3" class="data row3 col3" >11.542284</td>
#       <td id="T_ea280_row3_col4" class="data row3 col4" >11.534641</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ea280_row4_col0" class="data row4 col0" >11.622021</td>
#       <td id="T_ea280_row4_col1" class="data row4 col1" >11.558985</td>
#       <td id="T_ea280_row4_col2" class="data row4 col2" >11.538387</td>
#       <td id="T_ea280_row4_col3" class="data row4 col3" >11.530090</td>
#       <td id="T_ea280_row4_col4" class="data row4 col4" >11.525997</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ea280_row5_col0" class="data row5 col0" >11.584894</td>
#       <td id="T_ea280_row5_col1" class="data row5 col1" >11.541698</td>
#       <td id="T_ea280_row5_col2" class="data row5 col2" >11.528889</td>
#       <td id="T_ea280_row5_col3" class="data row5 col3" >11.523874</td>
#       <td id="T_ea280_row5_col4" class="data row5 col4" >11.521103</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_ea280_row6_col0" class="data row6 col0" >11.562260</td>
#       <td id="T_ea280_row6_col1" class="data row6 col1" >11.532400</td>
#       <td id="T_ea280_row6_col2" class="data row6 col2" >11.523680</td>
#       <td id="T_ea280_row6_col3" class="data row6 col3" >11.520172</td>
#       <td id="T_ea280_row6_col4" class="data row6 col4" >11.517918</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_ea280_row7_col0" class="data row7 col0" >11.548525</td>
#       <td id="T_ea280_row7_col1" class="data row7 col1" >11.526529</td>
#       <td id="T_ea280_row7_col2" class="data row7 col2" >11.520222</td>
#       <td id="T_ea280_row7_col3" class="data row7 col3" >11.517506</td>
#       <td id="T_ea280_row7_col4" class="data row7 col4" >11.515524</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_ea280_row8_col0" class="data row8 col0" >11.539778</td>
#       <td id="T_ea280_row8_col1" class="data row8 col1" >11.522627</td>
#       <td id="T_ea280_row8_col2" class="data row8 col2" >11.517862</td>
#       <td id="T_ea280_row8_col3" class="data row8 col3" >11.515522</td>
#       <td id="T_ea280_row8_col4" class="data row8 col4" >11.513691</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_ea280_row9_col0" class="data row9 col0" >11.533905</td>
#       <td id="T_ea280_row9_col1" class="data row9 col1" >11.519743</td>
#       <td id="T_ea280_row9_col2" class="data row9 col2" >11.516026</td>
#       <td id="T_ea280_row9_col3" class="data row9 col3" >11.513891</td>
#       <td id="T_ea280_row9_col4" class="data row9 col4" >11.512203</td>
#     </tr>
#     <tr>
#       <th id="T_ea280_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_ea280_row10_col0" class="data row10 col0" >11.529690</td>
#       <td id="T_ea280_row10_col1" class="data row10 col1" >11.517746</td>
#       <td id="T_ea280_row10_col2" class="data row10 col2" >11.514685</td>
#       <td id="T_ea280_row10_col3" class="data row10 col3" >11.512665</td>
#       <td id="T_ea280_row10_col4" class="data row10 col4" >11.511145</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The relative error is calculated from the difference between the solution and the reference:
# $$
# \varepsilon_{rel} = \frac{g - g_{ref}}{g_{ref}}
# $$

# %%
error = (jnp.array([_gfunc.g[-1] for _gfunc in gfunc]).reshape(S_max, N_max).T - gfunc_reference.g[-1]) / gfunc_reference.g[-1]

# %%
# Format and print dataframe
df = pd.DataFrame(
    error,
    columns=[f'S = {_S}' for _S in jnp.arange(1, S_max + 1)],
    index=jnp.arange(1, N_max + 1))
df.index.name = 'N'
df.style.set_caption(r'Relative error on the $g$-function at $ln(t/t_s)=5$')
# Out:
# <style type="text/css">
# </style>
# <table id="T_faea0">
#   <caption>Relative error on the $g$-function at $ln(t/t_s)=5$</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faea0_level0_col0" class="col_heading level0 col0" >S = 1</th>
#       <th id="T_faea0_level0_col1" class="col_heading level0 col1" >S = 2</th>
#       <th id="T_faea0_level0_col2" class="col_heading level0 col2" >S = 3</th>
#       <th id="T_faea0_level0_col3" class="col_heading level0 col3" >S = 4</th>
#       <th id="T_faea0_level0_col4" class="col_heading level0 col4" >S = 5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >N</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faea0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_faea0_row0_col0" class="data row0 col0" >0.119108</td>
#       <td id="T_faea0_row0_col1" class="data row0 col1" >0.068803</td>
#       <td id="T_faea0_row0_col2" class="data row0 col2" >0.049834</td>
#       <td id="T_faea0_row0_col3" class="data row0 col3" >0.039130</td>
#       <td id="T_faea0_row0_col4" class="data row0 col4" >0.032013</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_faea0_row1_col0" class="data row1 col0" >0.050205</td>
#       <td id="T_faea0_row1_col1" class="data row1 col1" >0.026194</td>
#       <td id="T_faea0_row1_col2" class="data row1 col2" >0.017521</td>
#       <td id="T_faea0_row1_col3" class="data row1 col3" >0.012975</td>
#       <td id="T_faea0_row1_col4" class="data row1 col4" >0.010101</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_faea0_row2_col0" class="data row2 col0" >0.026429</td>
#       <td id="T_faea0_row2_col1" class="data row2 col1" >0.013066</td>
#       <td id="T_faea0_row2_col2" class="data row2 col2" >0.008371</td>
#       <td id="T_faea0_row2_col3" class="data row2 col3" >0.005834</td>
#       <td id="T_faea0_row2_col4" class="data row2 col4" >0.004356</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_faea0_row3_col0" class="data row3 col0" >0.015730</td>
#       <td id="T_faea0_row3_col1" class="data row3 col1" >0.007329</td>
#       <td id="T_faea0_row3_col2" class="data row3 col2" >0.004404</td>
#       <td id="T_faea0_row3_col3" class="data row3 col3" >0.003047</td>
#       <td id="T_faea0_row3_col4" class="data row3 col4" >0.002382</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_faea0_row4_col0" class="data row4 col0" >0.009976</td>
#       <td id="T_faea0_row4_col1" class="data row4 col1" >0.004498</td>
#       <td id="T_faea0_row4_col2" class="data row4 col2" >0.002708</td>
#       <td id="T_faea0_row4_col3" class="data row4 col3" >0.001987</td>
#       <td id="T_faea0_row4_col4" class="data row4 col4" >0.001631</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_faea0_row5_col0" class="data row5 col0" >0.006750</td>
#       <td id="T_faea0_row5_col1" class="data row5 col1" >0.002996</td>
#       <td id="T_faea0_row5_col2" class="data row5 col2" >0.001883</td>
#       <td id="T_faea0_row5_col3" class="data row5 col3" >0.001447</td>
#       <td id="T_faea0_row5_col4" class="data row5 col4" >0.001206</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_faea0_row6_col0" class="data row6 col0" >0.004783</td>
#       <td id="T_faea0_row6_col1" class="data row6 col1" >0.002188</td>
#       <td id="T_faea0_row6_col2" class="data row6 col2" >0.001430</td>
#       <td id="T_faea0_row6_col3" class="data row6 col3" >0.001125</td>
#       <td id="T_faea0_row6_col4" class="data row6 col4" >0.000929</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_faea0_row7_col0" class="data row7 col0" >0.003589</td>
#       <td id="T_faea0_row7_col1" class="data row7 col1" >0.001677</td>
#       <td id="T_faea0_row7_col2" class="data row7 col2" >0.001129</td>
#       <td id="T_faea0_row7_col3" class="data row7 col3" >0.000893</td>
#       <td id="T_faea0_row7_col4" class="data row7 col4" >0.000721</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_faea0_row8_col0" class="data row8 col0" >0.002829</td>
#       <td id="T_faea0_row8_col1" class="data row8 col1" >0.001338</td>
#       <td id="T_faea0_row8_col2" class="data row8 col2" >0.000924</td>
#       <td id="T_faea0_row8_col3" class="data row8 col3" >0.000721</td>
#       <td id="T_faea0_row8_col4" class="data row8 col4" >0.000562</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_faea0_row9_col0" class="data row9 col0" >0.002318</td>
#       <td id="T_faea0_row9_col1" class="data row9 col1" >0.001088</td>
#       <td id="T_faea0_row9_col2" class="data row9 col2" >0.000765</td>
#       <td id="T_faea0_row9_col3" class="data row9 col3" >0.000579</td>
#       <td id="T_faea0_row9_col4" class="data row9 col4" >0.000433</td>
#     </tr>
#     <tr>
#       <th id="T_faea0_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_faea0_row10_col0" class="data row10 col0" >0.001952</td>
#       <td id="T_faea0_row10_col1" class="data row10 col1" >0.000914</td>
#       <td id="T_faea0_row10_col2" class="data row10 col2" >0.000648</td>
#       <td id="T_faea0_row10_col3" class="data row10 col3" >0.000473</td>
#       <td id="T_faea0_row10_col4" class="data row10 col4" >0.000341</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plot error as function of N and S
fig, axs = plt.subplots(ncols=2, sharey=True, layout='constrained')

N = jnp.arange(1, N_max + 1)
S = jnp.arange(1, S_max + 1)

axs[0].set_xscale('function', functions=(lambda x: jnp.log(x), lambda x: jnp.exp(x)))
axs[0] = gs.plot._format_axis(axs[0], axis_labels=[r'$N$', r'$log_{10}(\varepsilon_{rel})$'])
axs[0].plot(N, jnp.log10(error), '-o');
axs[0].plot(N, jnp.log10(0.1 / N**2), 'k--');
axs[0].legend([f'$S={_S}$' for _S in S] + [r'$1 / N^2$'], frameon=False)

axs[1].set_xscale('function', functions=(lambda x: jnp.log(x), lambda x: jnp.exp(x)))
axs[1] = gs.plot._format_axis(axs[1])
axs[1].set_xlabel(r'S')
axs[1].plot(S, jnp.log10(error.T), '-o');
axs[1].plot(S, jnp.log10(0.01 / S), 'k--');
axs[1].set_xlim(None, 20)
axs[1].legend([f'$N={_N}$' for _N in N] + [r'$1 / S$'], frameon=False)

fig.set_size_inches(140. / 25.4, 90. / 25.4)
fig.savefig('convergence-Eskilson-optimal.eps')
